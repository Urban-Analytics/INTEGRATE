# %%
import pandas as pd
import geopandas as gpd
import os
from datetime import datetime
import re
import numpy as np
import folium
from shapely.geometry import Point
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import sys

from together import Together  # pip install together
sys.path.insert(1, '../')
from Functions import get_gentrification_scores, map_static, get_gentrification_scores_categorical

# %%
city = 'manchester'

# %%
neighbourhoods = gpd.read_file(f"../../../data/AirbnbData/airbnb-{city}/neighbourhoods.geojson")

# %% [markdown]
# ### Join together 4 sets of listings, removing duplicates

# %%
listings_mar = pd.read_csv(f"../../../data/AirbnbData/airbnb-{city}/listings_mar24.csv.gz")
listings_jun = pd.read_csv(f"../../../data/AirbnbData/airbnb-{city}/listings_jun24.csv.gz")
listings_sept = pd.read_csv(f"../../../data/AirbnbData/airbnb-{city}/listings_sept24.csv.gz")
listings_dec = pd.read_csv(f"../../../data/AirbnbData/airbnb-{city}/listings_dec24.csv.gz")

# %%
# Add a column indicating the source dataframe
listings_mar["source"] = "Mar"
listings_jun["source"] = "Jun"
listings_sept["source"] = "Sept"
listings_dec["source"] = "Dec"

# Concatenate the two dataframes
combined = pd.concat([listings_mar, listings_jun, listings_sept, listings_dec, ])

# Group by listing ID and collect sources
combined["source"] = combined.groupby(["id", "listing_url", 'name'])["source"].transform(lambda x: ", ".join(sorted(set(x))))

# Drop duplicates based on listing ID (keeping the first occurrence)
final_listings = combined.drop_duplicates(subset="id").reset_index(drop=True)
len(final_listings)
# Out:
# 10109

# %% [markdown]
# ### Count the number of listings in each LSOA

# %%
lsoas =  gpd.read_file('../../../data/SpatialData/LSOAs_2011/LSOA_2011_EW_BSC_V4.shp')
manc_lads = ['Manchester', 'Rochdale', 'Bolton', 'Bury', 'Wigan', 'Oldham',  'Trafford', 'Salford', 'Tameside', 'Stockport']
pattern = '|'.join(manc_lads)
manchester_lsoas =lsoas[lsoas['LSOA11NMW'].str.contains(pattern)]
manchester_lsoas.head()
# Out:
#        LSOA11CD     LSOA11NM    LSOA11NMW   BNG_E   BNG_N     LONG      LAT  \
# 4642  E01004766  Bolton 005A  Bolton 005A  371186  411551 -2.43686  53.5997
# 4643  E01004767  Bolton 005B  Bolton 005B  371871  411508 -2.42651  53.5994
# 4644  E01004768  Bolton 001A  Bolton 001A  370034  413227 -2.45443  53.6147
# 4645  E01004769  Bolton 003A  Bolton 003A  371943  412792 -2.42554  53.6109
# 4646  E01004770  Bolton 003B  Bolton 003B  372075  412156 -2.42349  53.6052
#
#                                   GlobalID  \
# 4642  29ec009d-28d2-4b2d-856d-0041ff7a2c28
# 4643  59bd0d32-eae4-42bc-a7f8-d6e76e7372e3
# 4644  9a70e214-0a97-4484-a7c2-d97bad70ecb2
# 4645  c06d3924-84ea-48c6-abd1-43632303a4f2
# 4646  7d761bb4-224f-4fc9-81b0-c7a843c07335
#
#                                                geometry
# 4642  POLYGON ((371525.9 411866.915, 371336.156 4111...
# 4643  POLYGON ((372192.155 411874.385, 372403.344 41...
# 4644  POLYGON ((370698.947 414430.285, 370868.309 41...
# 4645  POLYGON ((371827.566 413132.13, 372260.979 412...
# 4646  POLYGON ((372545.065 412625.806, 372192.155 41...

# %%
final_listings['geometry'] = final_listings.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)
final_listings_gdf = gpd.GeoDataFrame(final_listings, geometry='geometry', crs="EPSG:4326")
final_listings_gdf = final_listings_gdf.to_crs(manchester_lsoas.crs)
final_listings_gdf = gpd.sjoin(final_listings_gdf, manchester_lsoas[['LSOA11NM', 'geometry']], how='left', predicate='within')

# %%
# Find the most common score in each LSOA
count = final_listings_gdf.groupby("LSOA11NM").size()
count_filtered = count[count >8]
count_filtered.name = 'Count'
manchester_lsoas = manchester_lsoas.sort_values(by='LSOA11NM')
manchester_lsoas = manchester_lsoas.merge(count_filtered, on='LSOA11NM', how='left')

# %% [markdown]
# ### Filter to only keep LSOAs within a 6000m buffer zone of the centre of Manchester

# %%
# Reproject to a CRS with meters (British National Grid)
manchester_lsoas = manchester_lsoas.to_crs(epsg=27700)

# Define Manchester city centre point (in WGS84, then project)
city_centre_wgs84 = Point(-2.2426, 53.4808)  # approx lat/lon of Manchester city centre
city_centre_point = gpd.GeoSeries([city_centre_wgs84], crs='EPSG:4326').to_crs(epsg=27700).iloc[0]

# Filter polygons within a buffer distance (e.g., 3 km radius)
buffer = city_centre_point.buffer(6000)  # 3000 meters
central_lsoas = manchester_lsoas[manchester_lsoas.intersects(buffer)]

# %%
fig, axs = plt.subplots(ncols =2, figsize=(10, 6))  # Ensure equal subplot sizes
central_lsoas.plot(ax=axs[1], column ='Count',  legend=True)  # Disable auto legend
central_lsoas.plot(ax=axs[0],  legend=True)  # Disable auto legend
axs[1].set_title("Count")
axs[0].set_title("All")
# Out:
# Text(0.5, 1.0, 'All')

# %%
final_listings_gdf = final_listings_gdf[final_listings_gdf['LSOA11NM'].isin(central_lsoas['LSOA11NM'].unique())]
final_listings = final_listings_gdf.copy()
del final_listings['geometry']

# %%
# map_center = [final_listings["latitude"].mean(), final_listings["longitude"].mean()]

# # Create a Folium map
# m = folium.Map(location=map_center, zoom_start=12, tiles="CartoDB Positron")

# for _, row in final_listings.iterrows():
#     popup_text = (
#         f"Text: {row['source']}<br>"
#         f"Name: {row['name']}<br>")
#     # Assign color based on predefined mapping or default to gray
#     color = "purple" if "Jun" in row['source'] else "lime" if "Dec" in row['source'] else "yellow" if "Mar" in row['source'] else "black"

#     folium.CircleMarker(location=[row["latitude"], row["longitude"]], radius=3,color=color,fill=True,
#         fill_opacity=0.8,popup=folium.Popup(popup_text, max_width=300),).add_to(m)

# # Add layer control
# folium.LayerControl().add_to(m)
# display(m)

# %%
final_listings['text'] = np.where(
    final_listings[['description', 'neighborhood_overview']].isna().all(axis=1),  # Check if both are NaN
    np.nan,  # Assign NaN if both are NaN
    final_listings['description'].fillna('') + " " + final_listings['neighborhood_overview'].fillna(''))

final_listings[final_listings['text'].isna()][["description", "neighborhood_overview","text"]].head()
# Out:
#     description neighborhood_overview text
# 2           NaN                   NaN  NaN
# 12          NaN                   NaN  NaN
# 19          NaN                   NaN  NaN
# 21          NaN                   NaN  NaN
# 442         NaN                   NaN  NaN

# %% [markdown]
# ## The prompt

# %%
prompt_explanatory = f"""
You are an expert in urban studies with a deep understanding of gentrification and its portrayal in public discourse. I will provide you with Airbnb 
listings, including a description of the property and a neighborhood overview. Your task is to analyze these texts and assess the gentrification status 
of the area based on how the neighborhood is presented.

Focus primarily on the neighborhood overview and description, ignoring property-specific details like the number of bedrooms, amenities, or decor. 

Consider the following:
- Direct mentions of local attractions, businesses, or community features that suggest development or revitalization.
- Language that highlights cultural hotspots, boutique shops, trendy cafes, or artisanal markets.
- Descriptions that emphasize diversity, safety, or the presence of creative communities, as these can signal gentrification dynamics.
- Listings that avoid mentioning the neighborhood or speak only broadly about the city may imply that the immediate area lacks desirable features or is 
not a selling point. This absence of detail should inform your assessment.

Assign one of the following categories:
- "Established": A well-known, desirable area with stable appeal and little active change.
- "Gentrifying": Signs of recent or ongoing transformation, such as new businesses or cultural shifts.
- "Emerging": Early indicators of gentrification potential, like creative spaces or gradual commercial interest.
- "Undeveloped": Lacking indicators of gentrification, often reflected in vague or absent neighborhood descriptions.

If a listing genuinely lacks sufficient information to make any assessment (e.g., the text is too sparse), assign a score of 'NA' and briefly explain.

Provide your answer strictly in the format:
'1. Category. Reasoning.', '2. Category. Reasoning.', etc., without any additional explanation or commentary.
"""
prompt = prompt_explanatory

# %% [markdown]
# ## Decide whether to run LLM
# Decide whether to run the LLM or load a file of scores that has been previously calculated and saved

# %%
# Check for existing files
base_dir = os.path.expanduser(f"../../data/airbnb-{city}/")
base_filename = "airbnb_gentrification_scores_categorical_combined_listings_filtered"
file_extension = ".gpkg"

# List all matching files in the directory
matching_files = [
    f for f in sorted(os.listdir(base_dir))
    if re.match(f"{base_filename}_\\d{{2}}{file_extension}$", f)]
matching_files
# Out:
# []

# %%
# If there are matching files, find the most recent one
if matching_files:
    df = gpd.read_file(base_dir+matching_files[-1])
    print(f"Loaded file: {matching_files[-1]}")
else:
    # If no matching files are found
    print("No matching files found. 'df' will not be loaded.")
    df = None
# Out:
# No matching files found. 'df' will not be loaded.

# %%
RUN_LLM = True
if df is not None:
    print("Have already loaded a gentrification file, will not re-run the LLM.")
    RUN_LLM = False

RUN_LLM = True  # Optionally override

if RUN_LLM:
    print("Running LLM")
    # Get the API key from a file
    with open('together.ai_key.txt', 'r') as f:
        api_key = f.readline().strip()

    client = Together(api_key=api_key)

    # Sample for now?
    # df = final_listings.sample(20).copy()
    df = final_listings.copy()

    print(f"Will query the LM for {len(df)} items")

    assert len(df) < 11000, "Too many tweets to process in one go. Please reduce the number of tweets."

    # Ensure the index is consecutive and ascending
    df = df.reset_index(drop=True)
    # To store the results
    df['gentrification_prediction'] = None

    # Batch processing
    batch_size = 20
    for i in range(0, len(df), batch_size):
        # Get the batch of tweets
        batch_tweets = df.loc[i:i + batch_size - 1, :]

        # Get sentiments using the function
        print(f"Submitting batch {i//len(batch_tweets)+1} of {len(df)//len(batch_tweets)}...")

        ids, sentiments, explanations = get_gentrification_scores_categorical(
            batch_tweets, prompt, client, batch_index=i, max_tokens=1500)
        # Update the DataFrame with the predictions
        df.loc[ids, 'gentrification_prediction'] = sentiments
        df.loc[ids, 'explanation'] = explanations

        # Predictions should be integers
        # df.gentrification_prediction = df.gentrification_prediction.astype('Int64')

    print("Finished querying LLM. Now saving file")

    # Initialize counter and check for existing files
    counter = 1
    while True:
        filename = f"{base_filename}_{counter:02d}.csv"
        filepath = os.path.join(base_dir, filename)
        if not os.path.exists(filepath):
            break
        counter += 1
    df.to_csv(f"{filepath}")    
    # df.set_crs(epsg=4326, inplace=True)
    # df.to_file(filepath, layer="data", driver="GPKG")
    print(f"File saved as: {filepath}")
# Out:
# Running LLM
# Will query the LM for 6902 items
# Submitting batch 1 of 345...
# Submitting batch 2 of 345...
# Submitting batch 3 of 345...
# Submitting batch 4 of 345...
# Submitting batch 5 of 345...
# Submitting batch 6 of 345...
# Submitting batch 7 of 345...
# Submitting batch 8 of 345...
# Submitting batch 9 of 345...
# Submitting batch 10 of 345...
# Submitting batch 11 of 345...
# Submitting batch 12 of 345...
# Submitting batch 13 of 345...
# Submitting batch 14 of 345...
# Submitting batch 15 of 345...
# Submitting batch 16 of 345...
# Submitting batch 17 of 345...
# Submitting batch 18 of 345...
# Submitting batch 19 of 345...
# Submitting batch 20 of 345...
# Submitting batch 21 of 345...
# Submitting batch 22 of 345...
# Submitting batch 23 of 345...
# Submitting batch 24 of 345...
# Submitting batch 25 of 345...
# Submitting batch 26 of 345...
# Submitting batch 27 of 345...
# Submitting batch 28 of 345...
# Submitting batch 29 of 345...
# Submitting batch 30 of 345...
# Submitting batch 31 of 345...
# Submitting batch 32 of 345...
# Submitting batch 33 of 345...
# Submitting batch 34 of 345...
# Submitting batch 35 of 345...
# Submitting batch 36 of 345...
# Submitting batch 37 of 345...
# Submitting batch 38 of 345...
# Submitting batch 39 of 345...
# Submitting batch 40 of 345...
# Submitting batch 41 of 345...
# Submitting batch 42 of 345...
# Submitting batch 43 of 345...
# Submitting batch 44 of 345...
# Submitting batch 45 of 345...
# Submitting batch 46 of 345...
# Submitting batch 47 of 345...
# Submitting batch 48 of 345...
# Submitting batch 49 of 345...
# Submitting batch 50 of 345...
# Submitting batch 51 of 345...
# Submitting batch 52 of 345...
# Submitting batch 53 of 345...
# Submitting batch 54 of 345...
# Submitting batch 55 of 345...
# Submitting batch 56 of 345...
# Submitting batch 57 of 345...
# Submitting batch 58 of 345...
# Submitting batch 59 of 345...
# Submitting batch 60 of 345...
# Submitting batch 61 of 345...
# Submitting batch 62 of 345...
# Submitting batch 63 of 345...
# Submitting batch 64 of 345...
# Submitting batch 65 of 345...
# Submitting batch 66 of 345...
# Submitting batch 67 of 345...
# Submitting batch 68 of 345...
# Submitting batch 69 of 345...
# Submitting batch 70 of 345...
# Submitting batch 71 of 345...
# Submitting batch 72 of 345...
# Submitting batch 73 of 345...
# Submitting batch 74 of 345...
# Submitting batch 75 of 345...
# Submitting batch 76 of 345...
# Submitting batch 77 of 345...
# Submitting batch 78 of 345...
# Submitting batch 79 of 345...
# Submitting batch 80 of 345...
# Submitting batch 81 of 345...
# Submitting batch 82 of 345...
# Submitting batch 83 of 345...
# Submitting batch 84 of 345...
# Submitting batch 85 of 345...
# Submitting batch 86 of 345...
# Submitting batch 87 of 345...
# Submitting batch 88 of 345...
# Submitting batch 89 of 345...
# Submitting batch 90 of 345...
# Submitting batch 91 of 345...
# Submitting batch 92 of 345...
# Submitting batch 93 of 345...
# Submitting batch 94 of 345...
# Submitting batch 95 of 345...
# Submitting batch 96 of 345...
# Submitting batch 97 of 345...
# Submitting batch 98 of 345...
# Submitting batch 99 of 345...
# Submitting batch 100 of 345...
# Submitting batch 101 of 345...
# Submitting batch 102 of 345...
# Submitting batch 103 of 345...
# Submitting batch 104 of 345...
# Submitting batch 105 of 345...
# Submitting batch 106 of 345...
# Submitting batch 107 of 345...
# Submitting batch 108 of 345...
# Submitting batch 109 of 345...
# Submitting batch 110 of 345...
# Submitting batch 111 of 345...
# Submitting batch 112 of 345...
# Submitting batch 113 of 345...
# Submitting batch 114 of 345...
# Submitting batch 115 of 345...
# Submitting batch 116 of 345...
# Submitting batch 117 of 345...
# Submitting batch 118 of 345...
# Submitting batch 119 of 345...
# Submitting batch 120 of 345...
# Submitting batch 121 of 345...
# Submitting batch 122 of 345...
# Submitting batch 123 of 345...
# Submitting batch 124 of 345...
# Submitting batch 125 of 345...
# Submitting batch 126 of 345...
# Submitting batch 127 of 345...
# Submitting batch 128 of 345...
# Submitting batch 129 of 345...
# Submitting batch 130 of 345...
# Submitting batch 131 of 345...
# Submitting batch 132 of 345...
# Submitting batch 133 of 345...
# Submitting batch 134 of 345...
# Submitting batch 135 of 345...
# Submitting batch 136 of 345...
# Submitting batch 137 of 345...
# Submitting batch 138 of 345...
# Submitting batch 139 of 345...
# Submitting batch 140 of 345...
# Submitting batch 141 of 345...
# Submitting batch 142 of 345...
# Submitting batch 143 of 345...
# Submitting batch 144 of 345...
# Submitting batch 145 of 345...
#
# *********************
# Warning: Invalid format on line 0: '1. 4. Undeveloped. The listing focuses on nearby attractions and distances to city centers, but lacks specific details about the neighborhood itself.'.
# The full response was:
# 1. 4. Undeveloped. The listing focuses on nearby attractions and distances to city centers, but lacks specific details about the neighborhood itself.
# 2. 2. Gentrifying. The description highlights trendy areas like the Northern Quarter, mentions popular cafes, and notes easy access to shopping centers and transportation links.
# 3. 3. Emerging. The neighborhood is described as quiet, with the apartment being close to local amenities and public transport, but lacks specific details about cultural or commercial developments.
# 4. 3. Emerging. The listing mentions fantastic local bars and restaurants, but the description is general and doesn't provide specific details about the neighborhood's character or development.
# 5. 2. Gentrifying. The mention of a "cool eco coffee shop" and the overall tone suggest a trendy, upscale area with a focus on sustainability and creativity.
# 6. 3. Emerging. Similar to the previous listing, this one mentions local bars and restaurants, but the description is general and lacks specific details about the neighborhood's development or character.
# 7. NA. The listing lacks sufficient information to make an assessment, as it only mentions the apartment being suitable for a group trip without providing any neighborhood details.
# 8. 2. Gentrifying. The description highlights the apartment's luxurious features and its proximity to developed areas like Salford Quays and Media City, suggesting an area with significant investment and development.
# 9. 2. Gentrifying. The mention of a diverse atmosphere, commercial and residential areas, and proximity to the city stadium and concert halls suggests an area with a mix of old and new developments.
# 10. 2. Gentrifying. The description highlights the apartment's location in the heart of Manchester City Centre, specifically in China Town, and mentions its proximity to a variety of eateries, suggesting a vibrant and developed area.
# 11. NA. The listing lacks sufficient information to make an assessment, as it only provides a general description of the apartment without any neighborhood details.
# 12. NA. The listing lacks sufficient information to make an assessment, as it only mentions easy access to everything without providing any specific neighborhood details.
# 13. 1. Established. The description highlights the apartment's location in the "nicest part of Manchester's City Center" and its proximity to popular areas like Deansgate and Market Street, suggesting a well-established and desirable area.
# 14. 3. Emerging. The neighborhood is described as quiet and peaceful, but with direct access to the city centre, suggesting an area that is developing or transitioning.
# 15. 3. Emerging. Similar to the previous listing, this one describes the neighborhood as quiet and peaceful, but with direct access to the city centre, suggesting an area that is developing or transitioning.
# 16. 3. Emerging. The description is similar to the previous two listings, suggesting an area that is developing or transitioning.
# 17. 2. Gentrifying. The description highlights the property's location near Spinningfields and Salford Central, and mentions its proximity to a variety of amenities, suggesting an area with significant development and investment.
# 18. NA. The listing lacks sufficient information to make an assessment, as it only provides a general description of the property without any neighborhood details.
# 19. NA. The listing lacks sufficient information to make an assessment, as it only mentions easy access to everything without providing any specific neighborhood details.
# 20. 2. Gentrifying. The description highlights the apartment's location in the heart of the city, its contemporary design, and its proximity to popular areas like King Street, suggesting a vibrant and developed area.
# *********************
#
# Submitting batch 146 of 345...
# Submitting batch 147 of 345...
# Submitting batch 148 of 345...
# Submitting batch 149 of 345...
# Submitting batch 150 of 345...
# Submitting batch 151 of 345...
# Submitting batch 152 of 345...
# Submitting batch 153 of 345...
# Submitting batch 154 of 345...
# Submitting batch 155 of 345...
# Submitting batch 156 of 345...
# Submitting batch 157 of 345...
# Submitting batch 158 of 345...
# Submitting batch 159 of 345...
# Submitting batch 160 of 345...
# Submitting batch 161 of 345...
# Submitting batch 162 of 345...
# Submitting batch 163 of 345...
# Submitting batch 164 of 345...
# Submitting batch 165 of 345...
# Submitting batch 166 of 345...
# Submitting batch 167 of 345...
# Submitting batch 168 of 345...
# Submitting batch 169 of 345...
# Submitting batch 170 of 345...
# Submitting batch 171 of 345...
# Submitting batch 172 of 345...
# Submitting batch 173 of 345...
# Submitting batch 174 of 345...
# Submitting batch 175 of 345...
# Submitting batch 176 of 345...
# Submitting batch 177 of 345...
# Submitting batch 178 of 345...
# Submitting batch 179 of 345...
# Submitting batch 180 of 345...
# Submitting batch 181 of 345...
# Submitting batch 182 of 345...
# Submitting batch 183 of 345...
# Submitting batch 184 of 345...
# Submitting batch 185 of 345...
# Submitting batch 186 of 345...
# Submitting batch 187 of 345...
# Submitting batch 188 of 345...
# Submitting batch 189 of 345...
# Submitting batch 190 of 345...
# Submitting batch 191 of 345...
# Submitting batch 192 of 345...
# Submitting batch 193 of 345...
# Submitting batch 194 of 345...
# Submitting batch 195 of 345...
# Submitting batch 196 of 345...
# Submitting batch 197 of 345...
# Submitting batch 198 of 345...
# Submitting batch 199 of 345...
# Submitting batch 200 of 345...
# Submitting batch 201 of 345...
# Submitting batch 202 of 345...
# Submitting batch 203 of 345...
# Submitting batch 204 of 345...
# Submitting batch 205 of 345...
# Submitting batch 206 of 345...
# Submitting batch 207 of 345...
# Submitting batch 208 of 345...
# Submitting batch 209 of 345...
# Submitting batch 210 of 345...
# Submitting batch 211 of 345...
# Submitting batch 212 of 345...
# Submitting batch 213 of 345...
# Submitting batch 214 of 345...
# Submitting batch 215 of 345...
# Submitting batch 216 of 345...
# Submitting batch 217 of 345...
# Submitting batch 218 of 345...
# Submitting batch 219 of 345...
# Submitting batch 220 of 345...
# Submitting batch 221 of 345...
# Submitting batch 222 of 345...
# Submitting batch 223 of 345...
# Submitting batch 224 of 345...
# Submitting batch 225 of 345...
# Submitting batch 226 of 345...
# Submitting batch 227 of 345...
# Submitting batch 228 of 345...
# Submitting batch 229 of 345...
# Submitting batch 230 of 345...
# Submitting batch 231 of 345...
# Submitting batch 232 of 345...
# Submitting batch 233 of 345...
# Submitting batch 234 of 345...
# Submitting batch 235 of 345...
# Submitting batch 236 of 345...
# Submitting batch 237 of 345...
# Submitting batch 238 of 345...
# Submitting batch 239 of 345...
# Submitting batch 240 of 345...
# Submitting batch 241 of 345...
# Submitting batch 242 of 345...
# Submitting batch 243 of 345...
# Submitting batch 244 of 345...
# Submitting batch 245 of 345...
# Submitting batch 246 of 345...
# Submitting batch 247 of 345...
# Submitting batch 248 of 345...
# Submitting batch 249 of 345...
# Submitting batch 250 of 345...
# Submitting batch 251 of 345...
# Submitting batch 252 of 345...
# Submitting batch 253 of 345...
# Submitting batch 254 of 345...
# Submitting batch 255 of 345...
# Submitting batch 256 of 345...
# Submitting batch 257 of 345...
# Submitting batch 258 of 345...
# Submitting batch 259 of 345...
# Submitting batch 260 of 345...
# Submitting batch 261 of 345...
# Submitting batch 262 of 345...
# Submitting batch 263 of 345...
# Submitting batch 264 of 345...
# Submitting batch 265 of 345...
# Submitting batch 266 of 345...
# Submitting batch 267 of 345...
# Submitting batch 268 of 345...
# Submitting batch 269 of 345...
# Submitting batch 270 of 345...
# Submitting batch 271 of 345...
# Submitting batch 272 of 345...
# Submitting batch 273 of 345...
# Submitting batch 274 of 345...
# Submitting batch 275 of 345...
# Submitting batch 276 of 345...
# Submitting batch 277 of 345...
# Submitting batch 278 of 345...
# Submitting batch 279 of 345...
# Submitting batch 280 of 345...
# Submitting batch 281 of 345...
# Submitting batch 282 of 345...
# Submitting batch 283 of 345...
# Submitting batch 284 of 345...
# Submitting batch 285 of 345...
# Submitting batch 286 of 345...
# Submitting batch 287 of 345...
# Submitting batch 288 of 345...
# Submitting batch 289 of 345...
# Submitting batch 290 of 345...
# Submitting batch 291 of 345...
# Submitting batch 292 of 345...
# Submitting batch 293 of 345...
# Submitting batch 294 of 345...
# Submitting batch 295 of 345...
# Submitting batch 296 of 345...
# Submitting batch 297 of 345...
# Submitting batch 298 of 345...
# Submitting batch 299 of 345...
# Submitting batch 300 of 345...
# Submitting batch 301 of 345...
# Submitting batch 302 of 345...
# Submitting batch 303 of 345...
# Submitting batch 304 of 345...
# Submitting batch 305 of 345...
# Submitting batch 306 of 345...
# Submitting batch 307 of 345...
# Submitting batch 308 of 345...
# Submitting batch 309 of 345...
# Submitting batch 310 of 345...
# Submitting batch 311 of 345...
# Submitting batch 312 of 345...
# Submitting batch 313 of 345...
# Submitting batch 314 of 345...
# Submitting batch 315 of 345...
# Submitting batch 316 of 345...
# Submitting batch 317 of 345...
# Submitting batch 318 of 345...
# Submitting batch 319 of 345...
# Submitting batch 320 of 345...
# Submitting batch 321 of 345...
# Submitting batch 322 of 345...
# Submitting batch 323 of 345...
# Submitting batch 324 of 345...
# Submitting batch 325 of 345...
# Submitting batch 326 of 345...
# Submitting batch 327 of 345...
# Submitting batch 328 of 345...
# Submitting batch 329 of 345...
# Submitting batch 330 of 345...
# Submitting batch 331 of 345...
# Submitting batch 332 of 345...
# Submitting batch 333 of 345...
# Submitting batch 334 of 345...
# Submitting batch 335 of 345...
# Submitting batch 336 of 345...
# Submitting batch 337 of 345...
# Submitting batch 338 of 345...
# Submitting batch 339 of 345...
# Submitting batch 340 of 345...
# Submitting batch 341 of 345...
# Submitting batch 342 of 345...
# Submitting batch 343 of 345...
# Submitting batch 344 of 345...
# Submitting batch 345 of 345...
# Submitting batch 3451 of 3451...
# Finished querying LLM. Now saving file
# File saved as: ../../data/airbnb-manchester/airbnb_gentrification_scores_categorical_combined_listings_filtered_01.csv
