# %%
import pandas as pd
import geopandas as gpd
import os
from datetime import datetime
import re
import numpy as np
import folium
from shapely.geometry import Point
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import sys
import matplotlib as mpl

from together import Together  # pip install together
sys.path.insert(1, '../')
from Functions import get_gentrification_scores, map_static, get_gentrification_scores_categorical

# %%
city = 'manchester'

# %%
neighbourhoods = gpd.read_file(f"../../../data/AirbnbData/airbnb-{city}/neighbourhoods.geojson")

# %%
lsoas =  gpd.read_file('../../../data/SpatialData/LSOAs_2011/LSOA_2011_EW_BSC_V4.shp')
manc_lads = ['Manchester', 'Rochdale', 'Bolton', 'Bury', 'Wigan', 'Oldham',  'Trafford', 'Salford', 'Tameside', 'Stockport']
pattern = '|'.join(manc_lads)
manchester_lsoas =lsoas[lsoas['LSOA11NMW'].str.contains(pattern)]

# Reproject to a CRS with meters (British National Grid)
manchester_lsoas = manchester_lsoas.to_crs(epsg=27700)

# Define Manchester city centre point (in WGS84, then project)
city_centre_wgs84 = Point(-2.2426, 53.4808)  # approx lat/lon of Manchester city centre
city_centre_point = gpd.GeoSeries([city_centre_wgs84], crs='EPSG:4326').to_crs(epsg=27700).iloc[0]

# Filter polygons within a buffer distance (e.g., 3 km radius)
buffer = city_centre_point.buffer(6000)  # 3000 meters
central_lsoas = manchester_lsoas[manchester_lsoas.intersects(buffer)]

# %% [markdown]
# ### Join together 4 sets of listings, removing duplicates

# %%
listings_mar = pd.read_csv(f"../../../data/AirbnbData/airbnb-{city}/listings_mar24.csv.gz")
listings_jun = pd.read_csv(f"../../../data/AirbnbData/airbnb-{city}/listings_jun24.csv.gz")
listings_sept = pd.read_csv(f"../../../data/AirbnbData/airbnb-{city}/listings_sept24.csv.gz")
listings_dec = pd.read_csv(f"../../../data/AirbnbData/airbnb-{city}/listings_dec24.csv.gz")

# %%
# Add a column indicating the source dataframe
listings_mar["source"] = "Mar"
listings_jun["source"] = "Jun"
listings_sept["source"] = "Sept"
listings_dec["source"] = "Dec"

# Concatenate the two dataframes
combined = pd.concat([listings_mar, listings_jun, listings_sept, listings_dec, ], ignore_index=True)

# Group by listing ID and collect sources
# combined["source"] = combined.groupby(["id", "listing_url", 'name'])["source"].transform(lambda x: ", ".join(sorted(set(x))))
print(len(combined))

# Drop duplicates based on listing ID (keeping the first occurrence)
unique_listings = combined.drop_duplicates(subset=['id'], keep='first').copy()
print(len(unique_listings))
unique_listings = unique_listings.drop_duplicates(subset=['latitude', 'longitude'], keep='first').copy()
unique_listings = unique_listings.drop_duplicates(subset=['neighborhood_overview', 'description'], keep='first').copy()
print(len(unique_listings))
# Out:
# 26192
# 10109
# 8102

# %%
# duplicates = combined[combined.duplicated(subset=['id'], keep=False)]
# duplicates = duplicates.sort_values(by='id')

# %% [markdown]
# ### Add text columns combining description and neighbourhood overview

# %%
unique_listings['text'] = np.where(
    unique_listings[['description', 'neighborhood_overview']].isna().all(axis=1),  # Check if both are NaN
    np.nan,  # Assign NaN if both are NaN
    unique_listings['description'].fillna('') + " " + unique_listings['neighborhood_overview'].fillna(''))

# %% [markdown]
# ### Delete listings with no textual description

# %%
unique_listings[unique_listings['text'].isna()][["description", "neighborhood_overview","text"]]
unique_listings = unique_listings[unique_listings['text'].notnull()]
print(len(unique_listings))
# Out:
# 8101

# %% [markdown]
# ### Add spatial information to listings

# %%
unique_listings['geometry'] = unique_listings.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)
unique_listings_gdf = gpd.GeoDataFrame(unique_listings, geometry='geometry', crs="EPSG:4326")
unique_listings_gdf = unique_listings_gdf.to_crs(manchester_lsoas.crs)
unique_listings_gdf = gpd.sjoin(unique_listings_gdf, manchester_lsoas[['LSOA11NM', 'geometry']], how='left', predicate='within')

# %% [markdown]
# ### Count the number of listings in each LSOA

# %%
# Find the most common score in each LSOA
count = pd.DataFrame({'Count' : unique_listings_gdf.groupby("LSOA11NM").size()})
count.reset_index(inplace=True)
# count_filtered = count[count >8]
count_filtered=count
central_lsoas = central_lsoas.sort_values(by='LSOA11NM')
central_lsoas = central_lsoas.merge(count_filtered, on='LSOA11NM', how='left')

# %% [markdown]
# ### Filter to only keep LSOAs within a 6000m buffer zone of the centre of Manchester

# %%
fig, axs = plt.subplots(ncols=2, figsize=(8, 5), sharey=True)

central_lsoas.plot(ax=axs[0], color='lightgrey', edgecolor='black')
axs[0].set_title("All")

vmin = central_lsoas['Count'].min()
vmax = central_lsoas['Count'].max()
cmap = 'viridis'
central_lsoas.plot(column='Count', ax=axs[1], cmap=cmap, vmin=vmin, vmax=vmax, legend=False)
axs[1].set_title("Count")

# Build a ScalarMappable for the colorbar
sm = mpl.cm.ScalarMappable(cmap=cmap, norm=mpl.colors.Normalize(vmin=vmin, vmax=vmax))
sm._A = []

# Use the second axes' position to create a colorbar axis with identical height
pos = axs[1].get_position()  # Bbox: x0, y0, width, height in figure coords
cax = fig.add_axes([pos.x1 + 0.01, pos.y0, 0.02, pos.height])  # [left, bottom, width, height]
cbar = fig.colorbar(sm, cax=cax)
cbar.ax.tick_params(labelsize=8)

# %% [markdown]
# ### Keep only those in the central LSOAs

# %%
# unique_listings_gdf = unique_listings_gdf[unique_listings_gdf['LSOA11NM'].isin(central_lsoas['LSOA11NM'].unique())]
# del unique_listings_gdf['geometry']

# %% [markdown]
# ## The prompt

# %%
prompt_explanatory = f"""
You are an expert in urban studies with a deep understanding of gentrification and its portrayal in public discourse. I will provide you with Airbnb 
listings, including a description of the property and a neighborhood overview. Your task is to analyze these texts and assess the gentrification status 
of the area based on how the neighborhood is presented.

Focus primarily on the neighborhood overview and description, ignoring property-specific details like the number of bedrooms, amenities, or decor. 

Consider the following:
- Direct mentions of local attractions, businesses, or community features that suggest development or revitalization.
- Language that highlights cultural hotspots, boutique shops, trendy cafes, or artisanal markets.
- Descriptions that emphasize diversity, safety, or the presence of creative communities, as these can signal gentrification dynamics.
- Listings that avoid mentioning the neighborhood or speak only broadly about the city may imply that the immediate area lacks desirable features or is 
not a selling point. This absence of detail should inform your assessment.

Assign one of the following categories:
- "Established": A well-known, desirable area with stable appeal and little active change.
- "Gentrifying": Signs of recent or ongoing transformation, such as new businesses or cultural shifts.
- "Emerging": Early indicators of gentrification potential, like creative spaces or gradual commercial interest.
- "Undeveloped": Lacking indicators of gentrification, often reflected in vague or absent neighborhood descriptions.

If a listing genuinely lacks sufficient information to make any assessment (e.g., the text is too sparse), assign a score of 'NA' and briefly explain.

Provide your answer strictly in the format:
'1. Category. Reasoning.', '2. Category. Reasoning.', etc., without any additional explanation or commentary.
"""
prompt = prompt_explanatory

# %% [markdown]
# ## Decide whether to run LLM
# Decide whether to run the LLM or load a file of scores that has been previously calculated and saved

# %%
# Check for existing files
base_dir = os.path.expanduser(f"../../../data/AirbnbData/airbnb-{city}/")
base_filename = "airbnb_gentrification_scores_new"
file_extension = ".gpkg"

# List all matching files in the directory
matching_files = [
    f for f in sorted(os.listdir(base_dir))
    if re.match(f"{base_filename}_\\d{{2}}{file_extension}$", f)]
matching_files
# Out:
# []

# %%
# If there are matching files, find the most recent one
if matching_files:
    df = gpd.read_file(base_dir+matching_files[-1])
    print(f"Loaded file: {matching_files[-1]}")
else:
    # If no matching files are found
    print("No matching files found. 'df' will not be loaded.")
    df = None
# Out:
# No matching files found. 'df' will not be loaded.

# %%
RUN_LLM = True
if df is not None:
    print("Have already loaded a gentrification file, will not re-run the LLM.")
    RUN_LLM = False

RUN_LLM = True  # Optionally override

if RUN_LLM:
    print("Running LLM")
    # Get the API key from a file
    with open('../together.ai_key.txt', 'r') as f:
        api_key = f.readline().strip()

    client = Together(api_key=api_key)

    # Sample for now?
    # df = final_listings.sample(20).copy()
    df = deduplicated_listings.copy()

    print(f"Will query the LM for {len(df)} items")

    assert len(df) < 11000, "Too many tweets to process in one go. Please reduce the number of tweets."

    # Ensure the index is consecutive and ascending
    df = df.reset_index(drop=True)
    # To store the results
    df['gentrification_prediction'] = None

    # Batch processing
    batch_size = 20
    for i in range(0, len(df), batch_size):
        # Get the batch of tweets
        batch_tweets = df.loc[i:i + batch_size - 1, :]

        # Get sentiments using the function
        print(f"Submitting batch {i//len(batch_tweets)+1} of {len(df)//len(batch_tweets)}...")

        ids, sentiments, explanations = get_gentrification_scores_categorical(
            batch_tweets, prompt, client, batch_index=i, max_tokens=1500)
        # Update the DataFrame with the predictions
        df.loc[ids, 'gentrification_prediction'] = sentiments
        df.loc[ids, 'explanation'] = explanations

        # Predictions should be integers
        # df.gentrification_prediction = df.gentrification_prediction.astype('Int64')

    print("Finished querying LLM. Now saving file")

    # Initialize counter and check for existing files
    counter = 1
    while True:
        filename = f"{base_filename}_{counter:02d}.csv"
        filepath = os.path.join(base_dir, filename)
        if not os.path.exists(filepath):
            break
        counter += 1
    df.to_csv(f"{filepath}")    
    # df.set_crs(epsg=4326, inplace=True)
    # df.to_file(filepath, layer="data", driver="GPKG")
    print(f"File saved as: {filepath}")
# Out:
# Running LLM
# Will query the LM for 6323 items
# Submitting batch 1 of 316...
# Submitting batch 2 of 316...
# Submitting batch 3 of 316...
# Submitting batch 4 of 316...
# Submitting batch 5 of 316...
# Submitting batch 6 of 316...
# Submitting batch 7 of 316...
# Submitting batch 8 of 316...
# Submitting batch 9 of 316...
# Submitting batch 10 of 316...
# Submitting batch 11 of 316...
# Submitting batch 12 of 316...
# Submitting batch 13 of 316...
# Submitting batch 14 of 316...
# Submitting batch 15 of 316...
# Submitting batch 16 of 316...
# Submitting batch 17 of 316...
# Submitting batch 18 of 316...
# Submitting batch 19 of 316...
# Submitting batch 20 of 316...
# Submitting batch 21 of 316...
# Submitting batch 22 of 316...
# Submitting batch 23 of 316...
# Submitting batch 24 of 316...
# Submitting batch 25 of 316...
# Submitting batch 26 of 316...
# Submitting batch 27 of 316...
# Submitting batch 28 of 316...
# Submitting batch 29 of 316...
# Submitting batch 30 of 316...
# Submitting batch 31 of 316...
# Submitting batch 32 of 316...
# Submitting batch 33 of 316...
# Submitting batch 34 of 316...
# Submitting batch 35 of 316...
# Submitting batch 36 of 316...
# Submitting batch 37 of 316...
# Submitting batch 38 of 316...
# Submitting batch 39 of 316...
# Submitting batch 40 of 316...
# Submitting batch 41 of 316...
# Submitting batch 42 of 316...
# Submitting batch 43 of 316...
# Submitting batch 44 of 316...
# Submitting batch 45 of 316...
# Submitting batch 46 of 316...
# Submitting batch 47 of 316...
# Submitting batch 48 of 316...
# Submitting batch 49 of 316...
# Submitting batch 50 of 316...
# Submitting batch 51 of 316...
# Submitting batch 52 of 316...
# Submitting batch 53 of 316...
# Submitting batch 54 of 316...
# Submitting batch 55 of 316...
# Submitting batch 56 of 316...
# Submitting batch 57 of 316...
# Submitting batch 58 of 316...
# Submitting batch 59 of 316...
# Submitting batch 60 of 316...
# Submitting batch 61 of 316...
# Submitting batch 62 of 316...
# Submitting batch 63 of 316...
# Submitting batch 64 of 316...
# Submitting batch 65 of 316...
# Submitting batch 66 of 316...
# Submitting batch 67 of 316...
# Submitting batch 68 of 316...
# Submitting batch 69 of 316...
# Submitting batch 70 of 316...
# Submitting batch 71 of 316...
# Submitting batch 72 of 316...
# Submitting batch 73 of 316...
# Submitting batch 74 of 316...
# Submitting batch 75 of 316...
# Submitting batch 76 of 316...
# Submitting batch 77 of 316...
# Submitting batch 78 of 316...
# Submitting batch 79 of 316...
# Submitting batch 80 of 316...
# Submitting batch 81 of 316...
# Submitting batch 82 of 316...
# Submitting batch 83 of 316...
# Submitting batch 84 of 316...
# Submitting batch 85 of 316...
# Submitting batch 86 of 316...
# Submitting batch 87 of 316...
# Submitting batch 88 of 316...
# Submitting batch 89 of 316...
# Submitting batch 90 of 316...
# Submitting batch 91 of 316...
# Submitting batch 92 of 316...
# Submitting batch 93 of 316...
# Submitting batch 94 of 316...
# Submitting batch 95 of 316...
# Submitting batch 96 of 316...
# Submitting batch 97 of 316...
# Submitting batch 98 of 316...
# Submitting batch 99 of 316...
# Submitting batch 100 of 316...
# Submitting batch 101 of 316...
# Submitting batch 102 of 316...
# Submitting batch 103 of 316...
# Submitting batch 104 of 316...
# Submitting batch 105 of 316...
# Submitting batch 106 of 316...
# Submitting batch 107 of 316...
# Submitting batch 108 of 316...
# Submitting batch 109 of 316...
# Submitting batch 110 of 316...
# Submitting batch 111 of 316...
# Submitting batch 112 of 316...
# Submitting batch 113 of 316...
# Submitting batch 114 of 316...
# Submitting batch 115 of 316...
# Submitting batch 116 of 316...
# Submitting batch 117 of 316...
# Submitting batch 118 of 316...
# Submitting batch 119 of 316...
# Submitting batch 120 of 316...
# Submitting batch 121 of 316...
# Submitting batch 122 of 316...
# Submitting batch 123 of 316...
# Submitting batch 124 of 316...
# Submitting batch 125 of 316...
# Submitting batch 126 of 316...
# Submitting batch 127 of 316...
# Submitting batch 128 of 316...
# Submitting batch 129 of 316...
# Submitting batch 130 of 316...
# Submitting batch 131 of 316...
# Submitting batch 132 of 316...
# Submitting batch 133 of 316...
# Submitting batch 134 of 316...
# Submitting batch 135 of 316...
# Submitting batch 136 of 316...
# Submitting batch 137 of 316...
# Submitting batch 138 of 316...
# Submitting batch 139 of 316...
# Submitting batch 140 of 316...
# Submitting batch 141 of 316...
# Submitting batch 142 of 316...
# Submitting batch 143 of 316...
# Submitting batch 144 of 316...
# Submitting batch 145 of 316...
# Submitting batch 146 of 316...
# Submitting batch 147 of 316...
# Submitting batch 148 of 316...
# Submitting batch 149 of 316...
# Submitting batch 150 of 316...
# Submitting batch 151 of 316...
# Submitting batch 152 of 316...
# Submitting batch 153 of 316...
# Submitting batch 154 of 316...
# Submitting batch 155 of 316...
# Submitting batch 156 of 316...
# Submitting batch 157 of 316...
# Submitting batch 158 of 316...
# Submitting batch 159 of 316...
# Submitting batch 160 of 316...
# Submitting batch 161 of 316...
# Submitting batch 162 of 316...
# Submitting batch 163 of 316...
# Submitting batch 164 of 316...
# Submitting batch 165 of 316...
# Submitting batch 166 of 316...
# Submitting batch 167 of 316...
# Submitting batch 168 of 316...
# Submitting batch 169 of 316...
# Submitting batch 170 of 316...
# Submitting batch 171 of 316...
# Submitting batch 172 of 316...
# Submitting batch 173 of 316...
# Submitting batch 174 of 316...
# Submitting batch 175 of 316...
# Submitting batch 176 of 316...
# Submitting batch 177 of 316...
# Submitting batch 178 of 316...
# Submitting batch 179 of 316...
# Submitting batch 180 of 316...
# Submitting batch 181 of 316...
# Submitting batch 182 of 316...
# Submitting batch 183 of 316...
# Submitting batch 184 of 316...
# Submitting batch 185 of 316...
# Submitting batch 186 of 316...
# Submitting batch 187 of 316...
# Submitting batch 188 of 316...
# Submitting batch 189 of 316...
# Submitting batch 190 of 316...
# Submitting batch 191 of 316...
# Submitting batch 192 of 316...
# Submitting batch 193 of 316...
# Submitting batch 194 of 316...
# Submitting batch 195 of 316...
# Submitting batch 196 of 316...
# Submitting batch 197 of 316...
# Submitting batch 198 of 316...
# Submitting batch 199 of 316...
# Submitting batch 200 of 316...
# Submitting batch 201 of 316...
# Submitting batch 202 of 316...
# Submitting batch 203 of 316...
# Submitting batch 204 of 316...
# Submitting batch 205 of 316...
# Submitting batch 206 of 316...
# Submitting batch 207 of 316...
# Submitting batch 208 of 316...
# Submitting batch 209 of 316...
# Submitting batch 210 of 316...
# Submitting batch 211 of 316...
# Submitting batch 212 of 316...
# Submitting batch 213 of 316...
# Submitting batch 214 of 316...
# Submitting batch 215 of 316...
# Submitting batch 216 of 316...
# Submitting batch 217 of 316...
# Submitting batch 218 of 316...
# Submitting batch 219 of 316...
# Submitting batch 220 of 316...
# Submitting batch 221 of 316...
# Submitting batch 222 of 316...
# Submitting batch 223 of 316...
# Submitting batch 224 of 316...
# Submitting batch 225 of 316...
# Submitting batch 226 of 316...
# Submitting batch 227 of 316...
# Submitting batch 228 of 316...
# Submitting batch 229 of 316...
# Submitting batch 230 of 316...
# Submitting batch 231 of 316...
# Submitting batch 232 of 316...
# Submitting batch 233 of 316...
# Submitting batch 234 of 316...
# Submitting batch 235 of 316...
# Submitting batch 236 of 316...
# Submitting batch 237 of 316...
# Submitting batch 238 of 316...
# Submitting batch 239 of 316...
# Submitting batch 240 of 316...
# Submitting batch 241 of 316...
# Submitting batch 242 of 316...
# Submitting batch 243 of 316...
# Submitting batch 244 of 316...
# Submitting batch 245 of 316...
# Submitting batch 246 of 316...
# Submitting batch 247 of 316...
# Submitting batch 248 of 316...
# Submitting batch 249 of 316...
# Submitting batch 250 of 316...
# Submitting batch 251 of 316...
# Submitting batch 252 of 316...
# Submitting batch 253 of 316...
# Submitting batch 254 of 316...
# Submitting batch 255 of 316...
# Submitting batch 256 of 316...
# Submitting batch 257 of 316...
# Submitting batch 258 of 316...
# Submitting batch 259 of 316...
# Submitting batch 260 of 316...
# Submitting batch 261 of 316...
# Submitting batch 262 of 316...
# Submitting batch 263 of 316...
# Submitting batch 264 of 316...
# Submitting batch 265 of 316...
# Submitting batch 266 of 316...
# Submitting batch 267 of 316...
# Submitting batch 268 of 316...
# Submitting batch 269 of 316...
# Submitting batch 270 of 316...
# Submitting batch 271 of 316...
# Submitting batch 272 of 316...
# Submitting batch 273 of 316...
# Submitting batch 274 of 316...
# Submitting batch 275 of 316...
# Submitting batch 276 of 316...
# Submitting batch 277 of 316...
# Submitting batch 278 of 316...
# Submitting batch 279 of 316...
# Submitting batch 280 of 316...
# Submitting batch 281 of 316...
# Submitting batch 282 of 316...
# Submitting batch 283 of 316...
# Submitting batch 284 of 316...
# Submitting batch 285 of 316...
# Submitting batch 286 of 316...
# Submitting batch 287 of 316...
# Submitting batch 288 of 316...
# Submitting batch 289 of 316...
# Submitting batch 290 of 316...
# Submitting batch 291 of 316...
# Submitting batch 292 of 316...
# Submitting batch 293 of 316...
# Submitting batch 294 of 316...
# Submitting batch 295 of 316...
# Submitting batch 296 of 316...
# Submitting batch 297 of 316...
# Submitting batch 298 of 316...
# Submitting batch 299 of 316...
# Submitting batch 300 of 316...
# Submitting batch 301 of 316...
# Submitting batch 302 of 316...
# Submitting batch 303 of 316...
# Submitting batch 304 of 316...
# Submitting batch 305 of 316...
# Submitting batch 306 of 316...
# Submitting batch 307 of 316...
# Submitting batch 308 of 316...
# Submitting batch 309 of 316...
# Submitting batch 310 of 316...
# Submitting batch 311 of 316...
# Submitting batch 312 of 316...
# Submitting batch 313 of 316...
# Submitting batch 314 of 316...
# Submitting batch 315 of 316...
# Submitting batch 316 of 316...
# Submitting batch 2107 of 2107...
# Finished querying LLM. Now saving file
# File saved as: ../../../data/AirbnbData/airbnb-manchester/airbnb_gentrification_scores_new_01.csv
