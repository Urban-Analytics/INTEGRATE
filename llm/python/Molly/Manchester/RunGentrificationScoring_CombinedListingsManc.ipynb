# %%
import pandas as pd
import geopandas as gpd
import os
from datetime import datetime
import re
import numpy as np
import folium
from shapely.geometry import Point
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import sys
import matplotlib as mpl

from together import Together  # pip install together
sys.path.insert(1, '../')
from Functions import get_gentrification_scores, map_static, get_gentrification_scores_categorical

# %%
city = 'manchester'

# %%
neighbourhoods = gpd.read_file(f"../../../data/AirbnbData/airbnb-{city}/neighbourhoods.geojson")

# %%
lsoas =  gpd.read_file('../../../data/SpatialData/LSOAs_2011/LSOA_2011_EW_BSC_V4.shp')
manc_lads = ['Manchester', 'Rochdale', 'Bolton', 'Bury', 'Wigan', 'Oldham',  'Trafford', 'Salford', 'Tameside', 'Stockport']
pattern = '|'.join(manc_lads)
manchester_lsoas =lsoas[lsoas['LSOA11NMW'].str.contains(pattern)]

# Reproject to a CRS with meters (British National Grid)
manchester_lsoas = manchester_lsoas.to_crs(epsg=27700)

# Define Manchester city centre point (in WGS84, then project)
city_centre_wgs84 = Point(-2.2426, 53.4808)  # approx lat/lon of Manchester city centre
city_centre_point = gpd.GeoSeries([city_centre_wgs84], crs='EPSG:4326').to_crs(epsg=27700).iloc[0]

# Filter polygons within a buffer distance (e.g., 3 km radius)
buffer = city_centre_point.buffer(6000)  # 3000 meters
central_lsoas = manchester_lsoas[manchester_lsoas.intersects(buffer)]

# %%
manchester_lsoas.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Join together 4 sets of listings, removing duplicates

# %%
listings_mar = pd.read_csv(f"../../../data/AirbnbData/airbnb-{city}/listings_mar24.csv.gz")
listings_jun = pd.read_csv(f"../../../data/AirbnbData/airbnb-{city}/listings_jun24.csv.gz")
listings_sept = pd.read_csv(f"../../../data/AirbnbData/airbnb-{city}/listings_sept24.csv.gz")
listings_dec = pd.read_csv(f"../../../data/AirbnbData/airbnb-{city}/listings_dec24.csv.gz")

# %%
# Add a column indicating the source dataframe
listings_mar["source"] = "Mar"
listings_jun["source"] = "Jun"
listings_sept["source"] = "Sept"
listings_dec["source"] = "Dec"

# Concatenate the two dataframes
combined = pd.concat([listings_mar, listings_jun, listings_sept, listings_dec, ], ignore_index=True)

# Group by listing ID and collect sources
# combined["source"] = combined.groupby(["id", "listing_url", 'name'])["source"].transform(lambda x: ", ".join(sorted(set(x))))
print(len(combined))

# Drop duplicates based on listing ID (keeping the first occurrence)
unique_listings = combined.drop_duplicates(subset=['id'], keep='first').copy()
print(len(unique_listings))
unique_listings = unique_listings.drop_duplicates(subset=['latitude', 'longitude'], keep='first').copy()
print(len(unique_listings))
unique_listings = unique_listings.drop_duplicates(subset=['neighborhood_overview', 'description'], keep='first').copy()
print(len(unique_listings))
# Out:
# 26192
# 10109
# 9668
# 8102

# %%
# duplicates = combined[combined.duplicated(subset=['id'], keep=False)]
# duplicates = duplicates.sort_values(by='id')

# %% [markdown]
# ### Add text columns combining description and neighbourhood overview

# %%
unique_listings['text'] = np.where(
    unique_listings[['description', 'neighborhood_overview']].isna().all(axis=1),  # Check if both are NaN
    np.nan,  # Assign NaN if both are NaN
    unique_listings['description'].fillna('') + " " + unique_listings['neighborhood_overview'].fillna(''))

# %% [markdown]
# ### Delete listings with no textual description

# %%
unique_listings[unique_listings['text'].isna()][["description", "neighborhood_overview","text"]]
unique_listings = unique_listings[unique_listings['text'].notnull()]
print(len(unique_listings))
# Out:
# 8101

# %% [markdown]
# ### Add spatial information to listings

# %%
unique_listings['geometry'] = unique_listings.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)
unique_listings_gdf = gpd.GeoDataFrame(unique_listings, geometry='geometry', crs="EPSG:4326")
unique_listings_gdf = unique_listings_gdf.to_crs(manchester_lsoas.crs)
unique_listings_gdf = gpd.sjoin(unique_listings_gdf, manchester_lsoas[['LSOA11NM', 'geometry']], how='left', predicate='within')
# Out:
# /tmp/ipykernel_1222/1713514458.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_listings['geometry'] = unique_listings.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)

# %% [markdown]
# ### Remove even more duplicates

# %%
import networkx as nx
from itertools import combinations
from fuzzywuzzy import fuzz

def deduplicate_with_logging(df, lsoa_name):
    if len(df) < 2:
        return df  # Nothing to compare

    G = nx.Graph()
    G.add_nodes_from(df.index)

    # Keep track of reasons (scores)
    match_log = []

    for i, j in combinations(df.index, 2):
        score = fuzz.ratio(df.at[i, 'text'], df.at[j, 'text'])
        if score >= 75:
            G.add_edge(i, j)
            match_log.append((i, j, score))

    groups = list(nx.connected_components(G))
    unique_indices = [sorted(group)[0] for group in groups]

    # LOG: Print duplicates
    for group in groups:
        if len(group) > 1:
            print(f"\nDuplicates in {lsoa_name}:")
            for idx in sorted(group):
                text_snippet = df.at[idx, 'text'][:100].replace('\n', ' ')
                row = df.loc[idx]
                print(f" - id={row['id']} | lat={row['latitude']} | lon={row['longitude']} "
                      f"| snippet='{text_snippet}'")

            print("  Reasons (pairwise similarity scores):")
            for i, j, score in match_log:
                if i in group and j in group:
                    print(f"    {df.at[i, 'id']} ↔ {df.at[j, 'id']}: {score}")

    return df.loc[unique_indices]

results = []
for lsoa, group in unique_listings_gdf.groupby("LSOA11NM"):
    # check for duplicaed listings
    deduped = deduplicate_with_logging(group, lsoa)
   
    results.append(deduped)

# Combine results
deduplicated_listings = pd.concat(results).reset_index(drop=True)
print(len(deduplicated_listings))
# Out:
# Duplicates in Bolton 001B:
#  - id=28455562 | lat=53.63582 | lon=-2.4467 | snippet='Our House has an upstairs living arrangement, bedrooms  located on ground floor. Full of natural lig'
#  - id=28457161 | lat=53.6371 | lon=-2.44554 | snippet='Our House has an upstairs living arrangement, bedrooms  located on ground floor. Full of natural lig'
#  - id=53537286 | lat=53.63558 | lon=-2.44256 | snippet='Our House has an upstairs living arrangement, bedrooms located on ground floor. Full of natural ligh'
#   Reasons (pairwise similarity scores):
#     28455562 ↔ 28457161: 95
#     28455562 ↔ 53537286: 88
#     28457161 ↔ 53537286: 92
#
# Duplicates in Bolton 004A:
#  - id=25356651 | lat=53.60068 | lon=-2.55355 | snippet='THIS IS AN AIRBNB ROOM. NOT A HOTEL! <br /><br />On a main road. A short walk into Horwich Town Cent'
#  - id=26951925 | lat=53.59924 | lon=-2.55272 | snippet='On a main road. A short walk into Horwich Town Centre and a Middlebrook is about a 20 minute walk aw'
#   Reasons (pairwise similarity scores):
#     25356651 ↔ 26951925: 94
#
# Duplicates in Bolton 015A:
#  - id=883873010599794457 | lat=53.57939 | lon=-2.45524 | snippet='Welcome to our delightful 3-bedroom house in Bolton, a mere 5-minute drive from the centre and a  20'
#  - id=1158471065169048201 | lat=53.58343121011115 | lon=-2.4555231164911677 | snippet='Welcome to our delightful 3-bedroom house in Bolton, a mere 5-minute drive from the centre and a 20-'
#   Reasons (pairwise similarity scores):
#     883873010599794457 ↔ 1158471065169048201: 100
#
# Duplicates in Bolton 016E:
#  - id=21710662 | lat=53.57972 | lon=-2.42981 | snippet='Gordon Moon Suites are pleased to offer this bright, spacious, newly refurbished two bed apartment l'
#  - id=32356177 | lat=53.58 | lon=-2.42967 | snippet='Gordon Moon Suites are pleased to offer this bright, spacious, brand new one bedroom apartment locat'
#  - id=33063420 | lat=53.57998 | lon=-2.42966 | snippet='Gordon Moon Suites are pleased to offer this bright, spacious, brand new two bedroom apartment locat'
#  - id=33063517 | lat=53.58003 | lon=-2.42968 | snippet='Gordon Moon Suites are pleased to offer this bright, spacious, newly refurbished one bedroom apartme'
#  - id=33063524 | lat=53.57996 | lon=-2.42966 | snippet='Gordon Moon Suites are pleased to offer this bright, spacious, newly refurbished two bedroom apartme'
#  - id=1208452110625037641 | lat=53.58013592906951 | lon=-2.4300183068847603 | snippet='Gordon Moon Suites are pleased to offer this bright, spacious, brand new one bedroom apartment locat'
#   Reasons (pairwise similarity scores):
#     21710662 ↔ 32356177: 82
#     32356177 ↔ 33063420: 97
#     32356177 ↔ 33063517: 83
#     32356177 ↔ 33063524: 81
#     32356177 ↔ 1208452110625037641: 85
#     33063517 ↔ 33063524: 97
#
# Duplicates in Bolton 016E:
#  - id=588874957103211639 | lat=53.58067 | lon=-2.42653 | snippet='This modern 1 bedroom apartment in Bolton features stylish furnishings and modern appliances and is '
#  - id=838180939771839197 | lat=53.58070844789893 | lon=-2.4265605896055247 | snippet='This cozy 2 bedroom apartment in Bolton features stylish furnishings and modern appliances and is th'
#   Reasons (pairwise similarity scores):
#     588874957103211639 ↔ 838180939771839197: 77
#
# Duplicates in Bolton 016E:
#  - id=1034871302827365176 | lat=53.57795 | lon=-2.43796 | snippet='1 of 5 available in this block of apartments, it is homely yet central. Its close to all the importa'
#  - id=1038493538381639604 | lat=53.57794 | lon=-2.43756 | snippet='1 of 5 available in this block of apartments, it is homely yet central. Its close to all the importa'
#  - id=1038503309364748398 | lat=53.57640102981164 | lon=-2.4375055576085494 | snippet='3 of 5 available in this block of apartments, it is homely yet central. Its close to all the importa'
#   Reasons (pairwise similarity scores):
#     1034871302827365176 ↔ 1038493538381639604: 98
#     1034871302827365176 ↔ 1038503309364748398: 97
#     1038493538381639604 ↔ 1038503309364748398: 100
#
# Duplicates in Bolton 022E:
#  - id=1130534724453326450 | lat=53.5782138 | lon=-2.4262483 | snippet='About this space<br />This cozy studio apartment  in Bolton town centre features stylish furnishings'
#  - id=1164471303357671027 | lat=53.57807444116848 | lon=-2.426363155245781 | snippet='About this space<br />This cozy studio apartment  in Bolton town centre features stylish furnishings'
#   Reasons (pairwise similarity scores):
#     1130534724453326450 ↔ 1164471303357671027: 99
#
# Duplicates in Bolton 022E:
#  - id=1136784651460774595 | lat=53.57804916023101 | lon=-2.4262893944978714 | snippet='About this space<br />This cozy  one room studio in Bolton town centre features stylish furnishings '
#  - id=1142087400916351475 | lat=53.57678 | lon=-2.42525 | snippet='About this space<br />This cozy  one room studio in Bolton town centre features stylish furnishings '
#   Reasons (pairwise similarity scores):
#     1136784651460774595 ↔ 1142087400916351475: 83
#
# Duplicates in Bolton 028G:
#  - id=41630732 | lat=53.563 | lon=-2.5022 | snippet='Our cosy 18th Century beamed cottage is set in a little village in Bolton, on the edge of the West P'
#  - id=41905616 | lat=53.56456 | lon=-2.5034 | snippet='Our cosy 18th Century beamed cottage is set in a little village in Bolton, on the edge of the West P'
#   Reasons (pairwise similarity scores):
#     41630732 ↔ 41905616: 94
#
# Duplicates in Bolton 032B:
#  - id=1251488036835741075 | lat=53.54848 | lon=-2.39089 | snippet='This stylish and cozy living room is perfect for a relaxing stay. The space features a bold purple a'
#  - id=1262309649519954954 | lat=53.5492272 | lon=-2.3916682 | snippet='This stylish,cozy living room is perfect for a relaxing stay. The space features a bold purple accen'
#   Reasons (pairwise similarity scores):
#     1251488036835741075 ↔ 1262309649519954954: 86
#
# Duplicates in Bolton 032D:
#  - id=1209290619704471790 | lat=53.54117 | lon=-2.39564 | snippet='Relax with the whole family at this peaceful place to stay. there is a bathroom, kitchen,dining room'
#  - id=1209290626458669994 | lat=53.54217 | lon=-2.39247 | snippet='Relax with the  family at this peaceful place to stay also there is a kitchen, bathroom. Dining room'
#   Reasons (pairwise similarity scores):
#     1209290619704471790 ↔ 1209290626458669994: 76
#
# Duplicates in Bury 001B:
#  - id=672922864716213155 | lat=53.6633971452143 | lon=-2.2960031669342085 | snippet='Guests who visit Brook Bottom will return time and time again for romance, celebrations and escapes.'
#  - id=673094957495017567 | lat=53.66279 | lon=-2.297 | snippet='Guests who visit Brook Bottom will return time and time again for romance, celebrations and escapes.'
#  - id=673147975176281309 | lat=53.66402 | lon=-2.29585 | snippet='Guests who visit Brook Bottom will return time and time again for romance, celebrations and escapes.'
#   Reasons (pairwise similarity scores):
#     672922864716213155 ↔ 673094957495017567: 77
#     672922864716213155 ↔ 673147975176281309: 77
#     673094957495017567 ↔ 673147975176281309: 99
#
# Duplicates in Bury 020B:
#  - id=28242744 | lat=53.54776 | lon=-2.29308 | snippet='Luxury loft style apartment in the heart of Whitefield, Greater Manchester within an 18th century co'
#  - id=29899973 | lat=53.54779 | lon=-2.29302 | snippet='Large luxury apartment in the heart of Whitefield, Greater Manchester within an 18th century convert'
#   Reasons (pairwise similarity scores):
#     28242744 ↔ 29899973: 98
#
# Duplicates in Bury 022A:
#  - id=1234612464390919856 | lat=53.548096889206434 | lon=-2.256929206745919 | snippet='Luxury Back Garden Campsite, short walk to HEATON PARK. <br /><br />Campsite in the pretty village o'
#  - id=1236008402975893646 | lat=53.54801695094958 | lon=-2.257650000000002 | snippet='Luxury Back Garden Campsite, short walk to HEATON PARK. <br /><br />Campsite in the pretty village o'
#   Reasons (pairwise similarity scores):
#     1234612464390919856 ↔ 1236008402975893646: 89
#
# Duplicates in Bury 023B:
#  - id=25792093 | lat=53.53693 | lon=-2.27072 | snippet='Luxury Secure Campsite in a walled garden by the side of HEATON PARK. The campsite is within the gro'
#  - id=612822682864164824 | lat=53.53783 | lon=-2.2692 | snippet='Luxury Secure Campsite in a walled garden by the side of HEATON PARK. The campsite is within the gro'
#  - id=1079762847827334454 | lat=53.53713742742503 | lon=-2.26866261904908 | snippet='Luxury secure pop up camp site within a walled garden at the side of Heaton Park. The campsite is wi'
#  - id=1079837612891759139 | lat=53.53617437523444 | lon=-2.2703473235042773 | snippet='Luxury secure pop up camp site within a walled garden at the side of Heaton Park. The campsite is wi'
#  - id=1079843333895631000 | lat=53.53695756966311 | lon=-2.271008438245702 | snippet='Luxury secure pop up camp site within a walled garden at the side of Heaton Park. The campsite is wi'
#   Reasons (pairwise similarity scores):
#     25792093 ↔ 612822682864164824: 97
#     25792093 ↔ 1079762847827334454: 77
#     25792093 ↔ 1079837612891759139: 77
#     25792093 ↔ 1079843333895631000: 76
#     1079762847827334454 ↔ 1079837612891759139: 100
#     1079762847827334454 ↔ 1079843333895631000: 99
#     1079837612891759139 ↔ 1079843333895631000: 99
#
# Duplicates in Bury 024B:
#  - id=39618007 | lat=53.52078 | lon=-2.27598 | snippet='Lovely double glazed 2 bed, 1 bath flat located nearby Synagogues, shops and parks. <br />Manchester'
#  - id=47709351 | lat=53.52152 | lon=-2.27476 | snippet='Lovely double glazed 2 bed, 1 bath flat located nearby Synagogues, shops and parks.<br />Manchester '
#   Reasons (pairwise similarity scores):
#     39618007 ↔ 47709351: 77
#
# Duplicates in Manchester 002B:
#  - id=825907515801296004 | lat=53.53283 | lon=-2.21209 | snippet='Private double room in a quiet neighbourhood 15 minutes from the city centre '
#  - id=825914536132379839 | lat=53.53109 | lon=-2.2122 | snippet='Private double room (smallest room) in a quiet neighbourhood 15 minutes from the city centre '
#   Reasons (pairwise similarity scores):
#     825907515801296004 ↔ 825914536132379839: 91
#
# Duplicates in Manchester 003B:
#  - id=51697181 | lat=53.52988 | lon=-2.19873 | snippet='Room for two guests with a single and and double bed. A lovely place in a quiet neighborhood. Close '
#  - id=51697710 | lat=53.52877 | lon=-2.19943 | snippet='You’ll love the stylish decor of this charming place to stay.  A lovely place in a quiet neighborhoo'
#   Reasons (pairwise similarity scores):
#     51697181 ↔ 51697710: 80
#
# Duplicates in Manchester 003C:
#  - id=1140519423290294056 | lat=53.52111726035164 | lon=-2.1940328630380552 | snippet='welcome to our unique single bedroom  with strong WIFI for remote working. There is a shared living '
#  - id=1141213354795916060 | lat=53.52119202963348 | lon=-2.194870140916778 | snippet='Welcome  to our unique double bedroom  with strong WIFI for remote working. There is a shared living'
#   Reasons (pairwise similarity scores):
#     1140519423290294056 ↔ 1141213354795916060: 96
#
# Duplicates in Manchester 004A:
#  - id=919612438110836662 | lat=53.529668668180925 | lon=-2.232874282042751 | snippet='This stylish place to stay is perfect for individuals, couples and group trips.Located within 1.5 km'
#  - id=919612578910694026 | lat=53.527711914220845 | lon=-2.230553889980842 | snippet='This stylish place to stay is perfect for individuals, couples and  group trips.Located within 1.5 k'
#   Reasons (pairwise similarity scores):
#     919612438110836662 ↔ 919612578910694026: 99
#
# Duplicates in Manchester 006B:
#  - id=1057906615008539959 | lat=53.50984 | lon=-2.21439 | snippet='Forget your worries in this spacious and serene space. A place to rest from all activities '
#  - id=1057930102100821387 | lat=53.50967 | lon=-2.21462 | snippet='Forget your worries in this spacious and serene space. Wonderful spacious room. '
#   Reasons (pairwise similarity scores):
#     1057906615008539959 ↔ 1057930102100821387: 76
#
# Duplicates in Manchester 006D:
#  - id=890600846445006820 | lat=53.51575 | lon=-2.21003 | snippet='Warm and cosy Boutique Hotel styled room.<br />BREATHABLE MEMORY FOAM mattress.<br /><br />The House'
#  - id=721064881100331685 | lat=53.5166206 | lon=-2.2094037 | snippet='Warm and cosy Boutique Hotel styled room.<br />BREATHABLE MEMORY FOAM mattress. Ultra modern house w'
#   Reasons (pairwise similarity scores):
#     890600846445006820 ↔ 721064881100331685: 86
#
# Duplicates in Manchester 007A:
#  - id=1047036263706669927 | lat=53.5145435257056 | lon=-2.1950211667881256 | snippet='Welcome to our charming and spacious studio, a perfect retreat for travelers seeking comfort and con'
#  - id=1050683198672357554 | lat=53.51442788679522 | lon=-2.1950072525550453 | snippet='Welcome to our charming and spacious mini flats, a perfect retreat for travelers seeking comfort and'
#   Reasons (pairwise similarity scores):
#     1047036263706669927 ↔ 1050683198672357554: 81
#
# Duplicates in Manchester 007B:
#  - id=30574253 | lat=53.51086 | lon=-2.19979 | snippet='A cheerful room single bed. We are superhost in other listing of same house.It is 4 bedroom house, 1'
#  - id=594099126707274005 | lat=53.51075 | lon=-2.19868 | snippet='A lovely room in a very bright house,We are superhost in other listing of same house.It is 4 bedroom'
#   Reasons (pairwise similarity scores):
#     30574253 ↔ 594099126707274005: 94
#
# Duplicates in Manchester 007B:
#  - id=587412609782955069 | lat=53.5095 | lon=-2.20006 | snippet='Cheerful double bed bedroom. We are superhost in other listing of same house.<br /> It is 4 bedroom '
#  - id=593202792416372869 | lat=53.51087 | lon=-2.19869 | snippet='Very spacious bedroom available , We are superhost in other listing of same house.<br /> It is 4 bed'
#   Reasons (pairwise similarity scores):
#     587412609782955069 ↔ 593202792416372869: 92
#
# Duplicates in Manchester 007E:
#  - id=902983339952526067 | lat=53.51636 | lon=-2.19361 | snippet='The place is close to public transport (1min walk to bus stop), world markets, North Manc Hosp, park'
#  - id=908080161470380084 | lat=53.51653 | lon=-2.19404 | snippet='The place is close to public transport (1min walk to bus stop), world markets, North Manc Hosp, park'
#   Reasons (pairwise similarity scores):
#     902983339952526067 ↔ 908080161470380084: 84
#
# Duplicates in Manchester 008A:
#  - id=1073208669749608594 | lat=53.50711 | lon=-2.24232 | snippet='Cheetham Hill Guest House is located at central, ideal  location of  Cheetham Hill which is only 6 m'
#  - id=1075534129771128720 | lat=53.50816 | lon=-2.24081 | snippet='Studio in CheethamHill Guest House is located at central, ideal location of CheethamHill which is on'
#  - id=1075556382701087763 | lat=53.50735640049605 | lon=-2.2407929904015504 | snippet='En-suite TwinCheetham Hill Guest House is located at central, ideal location of Cheetham which is on'
#   Reasons (pairwise similarity scores):
#     1073208669749608594 ↔ 1075534129771128720: 96
#     1073208669749608594 ↔ 1075556382701087763: 95
#     1075534129771128720 ↔ 1075556382701087763: 97
#
# Duplicates in Manchester 008A:
#  - id=1155965494143761558 | lat=53.50874594376022 | lon=-2.240140065550804 | snippet='You will enjoy easy access to everything from this centrally located place.<br />7 minutes drive fro'
#  - id=1160218735177129984 | lat=53.50875 | lon=-2.23935 | snippet='You will enjoy easy access to everything from this centrally located place.<br />7 minutes drive fro'
#  - id=1171768042985564273 | lat=53.50826776663874 | lon=-2.240536212375798 | snippet='You will enjoy easy access to everything from this centrally located place.<br />7 minutes drive fro'
#   Reasons (pairwise similarity scores):
#     1155965494143761558 ↔ 1160218735177129984: 91
#     1155965494143761558 ↔ 1171768042985564273: 97
#     1160218735177129984 ↔ 1171768042985564273: 88
#
# Duplicates in Manchester 008D:
#  - id=22697157 | lat=53.5178 | lon=-2.24839 | snippet='All apartments come with an en suite bathroom plus a further second bathroom and a flat-screen TV. T'
#  - id=45731370 | lat=53.51711 | lon=-2.24888 | snippet='All apartments come with an en suite bathroom plus a further second bathroom and a flat-screen TV. T'
#  - id=682389357142804049 | lat=53.51851 | lon=-2.24874 | snippet='All apartments come with an en suite bathroom plus a further second bathroom and a flat-screen TV. T'
#   Reasons (pairwise similarity scores):
#     22697157 ↔ 45731370: 77
#     22697157 ↔ 682389357142804049: 77
#     45731370 ↔ 682389357142804049: 98
#
# Duplicates in Manchester 008D:
#  - id=51937482 | lat=53.51671 | lon=-2.24786 | snippet='This cute studio apartment is one of our latest in a collection of brand new refurbished units locat'
#  - id=51937493 | lat=53.51711 | lon=-2.24807 | snippet='This beautiful 2 bedroom apartment is our largest in a collection of brand new refurbished units loc'
#  - id=51937497 | lat=53.5163 | lon=-2.24663 | snippet='This beautiful 1.5 bedroom basement apartment is our latest in a collection of brand new refurbished'
#  - id=53902694 | lat=53.51813 | lon=-2.24653 | snippet='This 2 bedroom basement apartment is one of our largest in a collection of brand new refurbished uni'
#   Reasons (pairwise similarity scores):
#     51937482 ↔ 51937493: 88
#     51937482 ↔ 51937497: 89
#     51937482 ↔ 53902694: 87
#     51937493 ↔ 51937497: 89
#     51937493 ↔ 53902694: 93
#     51937497 ↔ 53902694: 86
#
# Duplicates in Manchester 009B:
#  - id=46368249 | lat=53.50915 | lon=-2.21588 | snippet='Just an 8 minute drive into Manchester city centre! A high-spec studio designed to host leisure and '
#  - id=46639749 | lat=53.50956 | lon=-2.21696 | snippet='Just an 8 minute drive into Manchester city centre! A high-spec studio designed to host leisure and '
#   Reasons (pairwise similarity scores):
#     46368249 ↔ 46639749: 81
#
# Duplicates in Manchester 009E:
#  - id=1297195342318137633 | lat=53.50747397579682 | lon=-2.190569478293631 | snippet='Egbert Escape - perfect for long stays!<br /><br />*4 bedrooms, 4 beds<br />*Bedroom 1 : Double bed<'
#  - id=1300630010017642446 | lat=53.507663025615 | lon=-2.18923978175611 | snippet='Egbert Escape - perfect for long term accommodation!<br /><br />*4 bedrooms, 4 beds<br />*Bedroom 1 '
#   Reasons (pairwise similarity scores):
#     1297195342318137633 ↔ 1300630010017642446: 98
#
# Duplicates in Manchester 011A:
#  - id=1086421049885965524 | lat=53.50410965093041 | lon=-2.17823881534424 | snippet='Kick back and relax in this calm, stylish space EtiCity. -3 Bedroom Semi near Etihad Football Stadiu'
#  - id=1099161642982542127 | lat=53.50310216177105 | lon=-2.179355876746682 | snippet='Kick back and relax in this calm, stylish space: EtiCity - 3 Bedroom Semi with Sky n Netflix near Et'
#   Reasons (pairwise similarity scores):
#     1086421049885965524 ↔ 1099161642982542127: 82
#
# Duplicates in Manchester 011D:
#  - id=30142101 | lat=53.49941 | lon=-2.17755 | snippet='Large room, everyone welcome friendly household that includes our cat. English and Spanish speaking '
#  - id=37806678 | lat=53.49946 | lon=-2.17595 | snippet='Large room, everyone welcome friendly household that includes our cat. English and a Spanish speakin'
#   Reasons (pairwise similarity scores):
#     30142101 ↔ 37806678: 98
#
# Duplicates in Manchester 012B:
#  - id=685538774121027835 | lat=53.483 | lon=-2.17662 | snippet='Kick back and relax in this calm, stylish space.<br /><br />There a super great transport link to to'
#  - id=685556124469715803 | lat=53.4831 | lon=-2.17691 | snippet='You will be sure to stay in a nice & safe house <br /><br />There a super great transport link to to'
#   Reasons (pairwise similarity scores):
#     685538774121027835 ↔ 685556124469715803: 81
#
# Duplicates in Manchester 013B:
#  - id=39314353 | lat=53.4918 | lon=-2.21505 | snippet='Being experienced host and traveler, I have learned most important values needed to add to my place.'
#  - id=39314523 | lat=53.49163 | lon=-2.21418 | snippet='Being experienced host and traveler, I have learned most important values needed to add to my place.'
#   Reasons (pairwise similarity scores):
#     39314353 ↔ 39314523: 98
#
# Duplicates in Manchester 013B:
#  - id=856828396740994273 | lat=53.49204 | lon=-2.2184 | snippet='20%OFF Weekly & Monthly Stays | Business | Insurance Stays | R<br /><br />🏳𝐅𝐔𝐑𝐍𝐈𝐒𝐇𝐄𝐃 𝐀𝐂𝐂𝐎𝐌𝐌𝐎𝐃𝐀𝐓𝐈𝐎𝐍 𝐒'
#  - id=894138752771311836 | lat=53.4914 | lon=-2.218 | snippet='20%OFF Weekly & Monthly Stays | Business | Insurance Stays | R<br /><br />🏳𝐅𝐔𝐑𝐍𝐈𝐒𝐇𝐄𝐃 𝐀𝐂𝐂𝐎𝐌𝐌𝐎𝐃𝐀𝐓𝐈𝐎𝐍 𝐒'
#   Reasons (pairwise similarity scores):
#     856828396740994273 ↔ 894138752771311836: 77
#
# Duplicates in Manchester 013C:
#  - id=52369483 | lat=53.48808 | lon=-2.21559 | snippet='(NOT entire house, this listing is for a private room in a shared house)<br />a large double room in'
#  - id=52404010 | lat=53.49007 | lon=-2.21536 | snippet='(NOT entire house, this listing is for a private room in a shared house)<br />a chic double Room in '
#  - id=52560218 | lat=53.48759 | lon=-2.21535 | snippet='(NOT entire house, this listing is for a private room in a shared house)<br />a spacious double Room'
#   Reasons (pairwise similarity scores):
#     52369483 ↔ 52404010: 89
#     52369483 ↔ 52560218: 94
#     52404010 ↔ 52560218: 99
#
# Duplicates in Manchester 013C:
#  - id=53112697 | lat=53.48994 | lon=-2.21528 | snippet='(NOT entire house, this listing is for a private room in a shared house)<br />a large double room in'
#  - id=549393533339575509 | lat=53.48763 | lon=-2.21494 | snippet='(NOT entire house, this listing is for a private room in a shared house)<br />a large double room in'
#   Reasons (pairwise similarity scores):
#     53112697 ↔ 549393533339575509: 96
#
# Duplicates in Manchester 013C:
#  - id=1084752897152479029 | lat=53.4890844 | lon=-2.2087971 | snippet='Enjoy a stylish experience in this ultra modern and centrally-located home. It is within walking dis'
#  - id=1103122604552613426 | lat=53.48871722170577 | lon=-2.2078224308995744 | snippet='Enjoy a stylish experience in this ultra modern and centrally-located home. It is within walking dis'
#   Reasons (pairwise similarity scores):
#     1084752897152479029 ↔ 1103122604552613426: 99
#
# Duplicates in Manchester 013D:
#  - id=8367483 | lat=53.48592 | lon=-2.22167 | snippet='(NOT entire house, this listing is for a private room in a shared house)<br />a spacious double Room'
#  - id=16870187 | lat=53.48667 | lon=-2.22031 | snippet='(NOT entire house, this listing is for a private room in a shared house)<br />a spacious en suite Ro'
#  - id=16871053 | lat=53.48701 | lon=-2.22013 | snippet='(NOT entire house, this listing is for a private room in a shared house)<br />a chic double Room in '
#  - id=17799147 | lat=53.48426 | lon=-2.22529 | snippet='(NOT entire house, this listing is for a private room in a shared house)<br />a spacious double Room'
#  - id=18094021 | lat=53.48717 | lon=-2.21989 | snippet='(NOT entire house, this listing is for a private room in a shared house)<br />a chic double Room in '
#  - id=563382773502898838 | lat=53.48598 | lon=-2.22175 | snippet='(NOT entire house, this listing is for a private room in a shared house)<br />a large room with King'
#   Reasons (pairwise similarity scores):
#     8367483 ↔ 16870187: 90
#     8367483 ↔ 16871053: 84
#     8367483 ↔ 17799147: 95
#     8367483 ↔ 18094021: 92
#     8367483 ↔ 563382773502898838: 89
#     16870187 ↔ 16871053: 89
#     16870187 ↔ 17799147: 90
#     16870187 ↔ 18094021: 85
#     16870187 ↔ 563382773502898838: 80
#     16871053 ↔ 17799147: 82
#     16871053 ↔ 18094021: 90
#     16871053 ↔ 563382773502898838: 78
#     17799147 ↔ 18094021: 83
#     17799147 ↔ 563382773502898838: 84
#     18094021 ↔ 563382773502898838: 87
#
# Duplicates in Manchester 013D:
#  - id=18140657 | lat=53.48783 | lon=-2.21936 | snippet='(NOT entire house, this listing is for a private room in a shared house)<br />a chic double Room in '
#  - id=562983530304629662 | lat=53.48567 | lon=-2.22124 | snippet='(NOT entire house, this listing is for a private room in a shared house)<br />a large king bed Room '
#   Reasons (pairwise similarity scores):
#     18140657 ↔ 562983530304629662: 90
#
# Duplicates in Manchester 013D:
#  - id=999359694849588128 | lat=53.48456901477597 | lon=-2.223314096295492 | snippet='Welcome to your cosy room in the heart of Ancoats, Manchester! If you're looking for a comfortable s'
#  - id=1000416593947191177 | lat=53.48302065541154 | lon=-2.223408183291815 | snippet='Welcome to your cosy room in the heart of Ancoats, Manchester! If you're looking for a comfortable s'
#   Reasons (pairwise similarity scores):
#     999359694849588128 ↔ 1000416593947191177: 98
#
# Duplicates in Manchester 013D:
#  - id=1013824835371693270 | lat=53.48351542322269 | lon=-2.221331812366641 | snippet='Spacious double with en-suite, 10-15 minute walk to centre of Manchester. Located in Ancoats which w'
#  - id=1020304150184093465 | lat=53.48475318084466 | lon=-2.2193782819587846 | snippet='Spacious King with en-suite, 10-15 minute walk to centre of Manchester. Located in Ancoats which was'
#  - id=1022316862575353082 | lat=53.48491588982159 | lon=-2.2213549897682703 | snippet='Cosy double with en-suite/private bathroom, 10-15 minute walk to centre of Manchester. Located in An'
#   Reasons (pairwise similarity scores):
#     1013824835371693270 ↔ 1020304150184093465: 97
#     1013824835371693270 ↔ 1022316862575353082: 91
#     1020304150184093465 ↔ 1022316862575353082: 93
#
# Duplicates in Manchester 013E:
#  - id=6914820 | lat=53.48136 | lon=-2.22016 | snippet='The Jacksonheim Boutique are delighted to offer our New York Boutique Apartment, comprising of an op'
#  - id=654923762606574977 | lat=53.4809847 | lon=-2.2188089 | snippet='The Heim Residences are delighted to offer our Manhattan apartment, comprising of a large open plan '
#   Reasons (pairwise similarity scores):
#     6914820 ↔ 654923762606574977: 80
#
# Duplicates in Manchester 013E:
#  - id=771571773039575480 | lat=53.48124 | lon=-2.22014 | snippet='A beautiful and stylish two-bedroom, two bathroom apartment in the heart of Manchester City centre w'
#  - id=912938223410856684 | lat=53.48092 | lon=-2.21966 | snippet='A beautiful and stylish two-bedroom, two bathroom apartment in the heart of Manchester City centre w'
#   Reasons (pairwise similarity scores):
#     771571773039575480 ↔ 912938223410856684: 82
#
# Duplicates in Manchester 013E:
#  - id=1201210074843460957 | lat=53.48274 | lon=-2.21989 | snippet='Cosy and Colourful room with storage, very comfortable double bed, desk and super fast Wi-Fi<br /><b'
#  - id=1201292206881741213 | lat=53.48255 | lon=-2.21994 | snippet='Cosy and colourful room with storage, very comfortable double bed, desk and super fast Wi-Fi<br /><b'
#   Reasons (pairwise similarity scores):
#     1201210074843460957 ↔ 1201292206881741213: 100
#
# Duplicates in Manchester 013F:
#  - id=771584777243999093 | lat=53.48021 | lon=-2.21917 | snippet='A beautiful and stylish two-bedroom, two bathroom apartment in the heart of Manchester City centre w'
#  - id=929640486614550639 | lat=53.47945942254898 | lon=-2.220007895262203 | snippet='Lavish are excited to host guests in this beautiful and stylish two-bedroom, two bathroom apartment '
#   Reasons (pairwise similarity scores):
#     771584777243999093 ↔ 929640486614550639: 90
#
# Duplicates in Manchester 013F:
#  - id=1089845070476367119 | lat=53.47912724198581 | lon=-2.2199493085301394 | snippet='Welcome to our fabulous property, ideal for LONG TERM STAYS<br /><br />You'll have exclusive access '
#  - id=1094858231078937890 | lat=53.4795807 | lon=-2.2207793 | snippet='Welcome to our fabulous property,<br /><br />You'll have exclusive access to the entire flat:<br /><'
#   Reasons (pairwise similarity scores):
#     1089845070476367119 ↔ 1094858231078937890: 92
#
# Duplicates in Manchester 013G:
#  - id=854168696254267193 | lat=53.4796 | lon=-2.21836 | snippet='A beautiful and stylish two bedroom, two bathroom apartment in the heart of Manchester City centre w'
#  - id=1081843397166538701 | lat=53.47982 | lon=-2.21834 | snippet='A beautiful and stylish two bedroom, two bathroom apartment in the heart of Manchester City centre w'
#   Reasons (pairwise similarity scores):
#     854168696254267193 ↔ 1081843397166538701: 85
#
# Duplicates in Manchester 013G:
#  - id=1216047224913073837 | lat=53.47914388132786 | lon=-2.21862235767212 | snippet='Luxurious 3-Bedroom Penthouse Near Manchester City Centre<br /><br />Discover the ultimate urban ret'
#  - id=1292007591908848257 | lat=53.47914691176451 | lon=-2.2186049446463585 | snippet='Luxurious 3-Bedroom Penthouse Near Manchester City Centre<br /><br />Discover the ultimate urban ret'
#   Reasons (pairwise similarity scores):
#     1216047224913073837 ↔ 1292007591908848257: 97
#
# Duplicates in Manchester 015A:
#  - id=1147319648984908220 | lat=53.48497 | lon=-2.1857987 | snippet='1 En-suite Bedroom Lovely Modern House<br />- 8 mins walk from Etihad - Manchester city stadium<br /'
#  - id=1147566631804676917 | lat=53.48474988320467 | lon=-2.186797942304078 | snippet='Enjoy a stylish experience at this centrally-located place.<br />- 8 mins walk from Etihad - Manches'
#   Reasons (pairwise similarity scores):
#     1147319648984908220 ↔ 1147566631804676917: 90
#
# Duplicates in Manchester 015C:
#  - id=10622228 | lat=53.47824 | lon=-2.20755 | snippet='It is a totally new house and furbished very well and quite nice. We want to earn a bit of money fro'
#  - id=11889175 | lat=53.47809 | lon=-2.20819 | snippet='It is a totally new house and furbished very well and quite nice. I want to earn a bit of money from'
#   Reasons (pairwise similarity scores):
#     10622228 ↔ 11889175: 98
#
# Duplicates in Manchester 015C:
#  - id=41050412 | lat=53.47697 | lon=-2.20616 | snippet='★ Please aware no party, no extra guests & visitors policy<br />★ Private Balcony in the room to enj'
#  - id=41047093 | lat=53.47625 | lon=-2.2075 | snippet='★ Please aware no party, no extra guests & visitors policy<br />★Private Ensuite with private Bathro'
#   Reasons (pairwise similarity scores):
#     41050412 ↔ 41047093: 78
#
# Duplicates in Manchester 015C:
#  - id=50562461 | lat=53.47668 | lon=-2.20628 | snippet='Aldridge House is a bright & spacious 4-bed, 2.5-bathroom house located within a short walk of the E'
#  - id=1187856797591645096 | lat=53.47694652526555 | lon=-2.206872196295171 | snippet='Stadium Drive House is a luxurious & very spacious 4-bedroom , 2.5-bathroom house located within a s'
#   Reasons (pairwise similarity scores):
#     50562461 ↔ 1187856797591645096: 87
#
# Duplicates in Manchester 015C:
#  - id=691933889871392947 | lat=53.47579 | lon=-2.20659 | snippet='A newly refurbished 5-bedroom Townhouse only a 5 min drive from the city centre, with free parking. '
#  - id=714899722844038147 | lat=53.47755 | lon=-2.20778 | snippet='A newly refurbished 4-bedroom Townhouse only a 5 min drive from the city centre, with free parking. '
#   Reasons (pairwise similarity scores):
#     691933889871392947 ↔ 714899722844038147: 80
#
# Duplicates in Manchester 015C:
#  - id=789821190989635894 | lat=53.47851 | lon=-2.20648 | snippet='This unique and stylish townhouse with magnificent views centrally located in a very peaceful quiet '
#  - id=800953388317606013 | lat=53.47723 | lon=-2.20705 | snippet='This unique & stylish townhouse with magnificent views centrally located in a very peaceful quiet su'
#   Reasons (pairwise similarity scores):
#     789821190989635894 ↔ 800953388317606013: 98
#
# Duplicates in Manchester 015C:
#  - id=1062617966117165688 | lat=53.476519543293 | lon=-2.208494716034176 | snippet='★ Private Bedroom with Balcony to enjoy the Beautiful City view<br />★ Double Bed with full memory f'
#  - id=1062721743344874036 | lat=53.477693365730815 | lon=-2.2070136870302224 | snippet='★ Private Cosy Bedroom <br />★ Double Bed with full memory foam mattress (No-Coil)<br />★ Shared: Ki'
#   Reasons (pairwise similarity scores):
#     1062617966117165688 ↔ 1062721743344874036: 94
#
# Duplicates in Manchester 015C:
#  - id=1110696412094988061 | lat=53.47488975786662 | lon=-2.20374923558198 | snippet='Large Private Room, in a shared house at the heart of buzzing Manchester presented by Peace Village '
#  - id=1110721028491918877 | lat=53.4749153 | lon=-2.2037546 | snippet='Large Private Ensuite Room, in a shared house at the heart of buzzing Manchester presented by Peace '
#   Reasons (pairwise similarity scores):
#     1110696412094988061 ↔ 1110721028491918877: 99
#
# Duplicates in Manchester 015C:
#  - id=1204859854212388260 | lat=53.47594 | lon=-2.20682 | snippet='One of the best locations in Manchester! You will absolutely fall in love with this home and here's '
#  - id=1308518791006609588 | lat=53.47719624079689 | lon=-2.201642314814892 | snippet='One of the best locations in Manchester! You will absolutely fall in love with this home and here's '
#   Reasons (pairwise similarity scores):
#     1204859854212388260 ↔ 1308518791006609588: 90
#
# Duplicates in Manchester 015C:
#  - id=1293611991243995767 | lat=53.47650032812143 | lon=-2.206729317213665 | snippet='Enjoy a stylish ✉ 𝗦𝗣𝗘𝗖𝗜𝗔𝗟 𝗥𝗔𝗧𝗘𝗦 𝗔𝗩𝗔𝗜𝗟𝗔𝗕𝗟𝗘 ✉  ★ Special Offer Available ★ Monthly Booking For 2024 Av'
#  - id=1300087656422811944 | lat=53.47646723380815 | lon=-2.204741585720947 | snippet='Enjoy a stylish ✉ 𝗦𝗣𝗘𝗖𝗜𝗔𝗟 𝗥𝗔𝗧𝗘𝗦 𝗔𝗩𝗔𝗜𝗟𝗔𝗕𝗟𝗘 ✉  ★ Special Offer Available ★ Monthly Booking For 2024 Av'
#   Reasons (pairwise similarity scores):
#     1293611991243995767 ↔ 1300087656422811944: 94
#
# Duplicates in Manchester 017D:
#  - id=1191326917496410621 | lat=53.46312 | lon=-2.17523 | snippet='Experience a relaxing stay in this comfortable 3-bedroom home, complete with a modern kitchen equipp'
#  - id=1242810839763123454 | lat=53.46362 | lon=-2.17677 | snippet='This property is ideal for professionals, contractors and temporary relocation purposes - offering a'
#   Reasons (pairwise similarity scores):
#     1191326917496410621 ↔ 1242810839763123454: 81
#
# Duplicates in Manchester 018B:
#  - id=921477868530893954 | lat=53.4652843 | lon=-2.221392 | snippet='Welcome:<br />Your booking secures one of the four rooms available. The property features a shared s'
#  - id=921491344721518175 | lat=53.46485983525067 | lon=-2.222215905160885 | snippet='Welcome:<br />Your booking secures one of the four rooms available. The property features a shared s'
#   Reasons (pairwise similarity scores):
#     921477868530893954 ↔ 921491344721518175: 100
#
# Duplicates in Manchester 018D:
#  - id=15802690 | lat=53.47087 | lon=-2.22739 | snippet='NEWLY REFURBISHED!!!<br /><br />One of the most popular Airbnbs in Manchester!!<br /><br />SERVICE F'
#  - id=16373844 | lat=53.47086 | lon=-2.22543 | snippet='SERVICE FEES COVERED! – Where some hosts add a Service Fee for the guests, we cover the fee for you!'
#  - id=31849737 | lat=53.47117 | lon=-2.22786 | snippet='SERVICE FEES COVERED! – Where some hosts add a Service Fee for the guests, we cover the fee for you!'
#  - id=39240120 | lat=53.47067 | lon=-2.22389 | snippet='SERVICE FEES COVERED! – Where some hosts add a Service Fee for the guests, we cover the fee for you!'
#  - id=50000645 | lat=53.47095 | lon=-2.22487 | snippet='Brand new!<br /><br />SERVICE FEES COVERED! – Where some hosts add a Service Fee for the guests, we '
#  - id=51355963 | lat=53.47024 | lon=-2.2248 | snippet='SERVICE FEES COVERED! – Where some hosts add a Service Fee for the guests, we cover the fee for you!'
#  - id=923670038798070477 | lat=53.47248088602261 | lon=-2.227297318249089 | snippet='SERVICE FEES COVERED! – Where some hosts add a Service Fee for the guests, we cover the fee for you!'
#  - id=1018761765496365024 | lat=53.47254812796432 | lon=-2.2269606602440803 | snippet='SERVICE FEES COVERED! – Where some hosts add a Service Fee for the guests, we cover the fee for you!'
#   Reasons (pairwise similarity scores):
#     15802690 ↔ 16373844: 92
#     15802690 ↔ 31849737: 92
#     15802690 ↔ 39240120: 92
#     15802690 ↔ 50000645: 90
#     15802690 ↔ 51355963: 92
#     15802690 ↔ 923670038798070477: 92
#     15802690 ↔ 1018761765496365024: 92
#     16373844 ↔ 31849737: 100
#     16373844 ↔ 39240120: 100
#     16373844 ↔ 50000645: 97
#     16373844 ↔ 51355963: 100
#     16373844 ↔ 923670038798070477: 100
#     16373844 ↔ 1018761765496365024: 92
#     31849737 ↔ 39240120: 100
#     31849737 ↔ 50000645: 97
#     31849737 ↔ 51355963: 100
#     31849737 ↔ 923670038798070477: 100
#     31849737 ↔ 1018761765496365024: 92
#     39240120 ↔ 50000645: 97
#     39240120 ↔ 51355963: 100
#     39240120 ↔ 923670038798070477: 100
#     39240120 ↔ 1018761765496365024: 92
#     50000645 ↔ 51355963: 97
#     50000645 ↔ 923670038798070477: 97
#     50000645 ↔ 1018761765496365024: 90
#     51355963 ↔ 923670038798070477: 100
#     51355963 ↔ 1018761765496365024: 92
#     923670038798070477 ↔ 1018761765496365024: 92
#
# Duplicates in Manchester 018D:
#  - id=654242732526242543 | lat=53.46836 | lon=-2.22578 | snippet='There are three rooms at this property, it is a house share, if you wish to book two rooms, please s'
#  - id=688459277253861907 | lat=53.4688 | lon=-2.2239 | snippet='There are three rooms at this property, it is a house share, if you wish to book two rooms, please s'
#  - id=867954048105517982 | lat=53.46912 | lon=-2.22528 | snippet='There are three rooms at this property, it is a house share, if you wish to book three rooms, please'
#   Reasons (pairwise similarity scores):
#     654242732526242543 ↔ 688459277253861907: 100
#     654242732526242543 ↔ 867954048105517982: 96
#     688459277253861907 ↔ 867954048105517982: 99
#
# Duplicates in Manchester 018D:
#  - id=1265071413456334745 | lat=53.47245217215736 | lon=-2.223504772799214 | snippet='Welcome to the Van Gogh Room, located in our charming guest house! This cosy space is designed for c'
#  - id=1265094298028984922 | lat=53.472474302276346 | lon=-2.2235386239425625 | snippet='Welcome to the Violin Room, located in our charming guest house! This cosy space is designed for com'
#   Reasons (pairwise similarity scores):
#     1265071413456334745 ↔ 1265094298028984922: 98
#
# Duplicates in Manchester 019A:
#  - id=22539566 | lat=53.46718 | lon=-2.24968 | snippet='Superb 2-bedroom apartment with superfast broadband and parking. Situated on a quiet street with fre'
#  - id=19674704 | lat=53.46249 | lon=-2.25147 | snippet='Superb 2-bedroom apartment with superfast broadband and parking. Situated on a quiet street with fre'
#   Reasons (pairwise similarity scores):
#     22539566 ↔ 19674704: 95
#
# Duplicates in Manchester 019A:
#  - id=955041256196153426 | lat=53.4600771 | lon=-2.2521385 | snippet='Relax with the whole family at this peaceful place to stay.<br />We are a married couple who live in'
#  - id=1105011654780024571 | lat=53.46008432920355 | lon=-2.252262644469738 | snippet='Kick back and relax in this calm, stylish space, close to different restaurants and shops such as KF'
#   Reasons (pairwise similarity scores):
#     955041256196153426 ↔ 1105011654780024571: 79
#
# Duplicates in Manchester 020B:
#  - id=35630886 | lat=53.46675 | lon=-2.18885 | snippet='This room is a spacious light double room with plenty of storage under beds and 2 built-in wardrobes'
#  - id=37449127 | lat=53.46625 | lon=-2.18953 | snippet='Located at the front of the house.This room is quite a small although still light and airy with plen'
#   Reasons (pairwise similarity scores):
#     35630886 ↔ 37449127: 78
#
# Duplicates in Manchester 021E:
#  - id=585305832262002579 | lat=53.45594 | lon=-2.15716 | snippet='Kick back and relax in this calm, stylish space a single room in our family house. '
#  - id=975997563881570281 | lat=53.456079132846845 | lon=-2.1560494950581743 | snippet='Kick back and relax in this calm, stylish space. A spacious single room in our lovely family house. '
#   Reasons (pairwise similarity scores):
#     585305832262002579 ↔ 975997563881570281: 91
#
# Duplicates in Manchester 022F:
#  - id=1105763188909800636 | lat=53.46210897463119 | lon=-2.2228030502624563 | snippet='Enjoy a comfortable stay at this ultra convenient, centrally located 1 bedroom flat. The universitie'
#  - id=1105775011470538110 | lat=53.46208342479026 | lon=-2.222781592590337 | snippet='Enjoy a comfortable stay at this ultra convenient, centrally located 1 bedroom flat. The universitie'
#  - id=1258919323286101870 | lat=53.46203610000001 | lon=-2.2230691 | snippet='Enjoy a comfortable stay at this ultra convenient, centrally located 2 bedroom flat that sleeps 3. T'
#  - id=1258946200117055487 | lat=53.461438891973216 | lon=-2.22172283165829 | snippet='Enjoy a comfortable stay at this ultra convenient, centrally located 2 bedroom flat that sleeps 4. T'
#  - id=1258963773646324116 | lat=53.46215564854361 | lon=-2.222297156781893 | snippet='Enjoy a comfortable stay at this ultra convenient, centrally located 2 bedroom flat that sleeps 4. T'
#   Reasons (pairwise similarity scores):
#     1105763188909800636 ↔ 1105775011470538110: 79
#     1105763188909800636 ↔ 1258919323286101870: 91
#     1105763188909800636 ↔ 1258946200117055487: 98
#     1105763188909800636 ↔ 1258963773646324116: 93
#     1105775011470538110 ↔ 1258946200117055487: 77
#     1258919323286101870 ↔ 1258946200117055487: 93
#     1258919323286101870 ↔ 1258963773646324116: 95
#     1258946200117055487 ↔ 1258963773646324116: 96
#
# Duplicates in Manchester 023C:
#  - id=23788479 | lat=53.4597 | lon=-2.17152 | snippet='Lovely bright, quiet double room in my 3 bed Edwardian home. Recently refurbished throughout, so eve'
#  - id=25378908 | lat=53.45976 | lon=-2.1729 | snippet='A lovely bright, quiet room in my 3 bed Edwardian home. Recently refurbished throughout, everything '
#   Reasons (pairwise similarity scores):
#     23788479 ↔ 25378908: 92
#
# Duplicates in Manchester 024B:
#  - id=1102455587391596846 | lat=53.45938445640502 | lon=-2.2553052753210068 | snippet='20 minutes on foot University of Manchester and MMU, 5 minutes on foot Library, Supermarket, Fitness'
#  - id=1102475519555507216 | lat=53.4594 | lon=-2.25531 | snippet='Enjoy this downtown home with family and friends and go anywhere.20 minutes on foot University of Ma'
#   Reasons (pairwise similarity scores):
#     1102455587391596846 ↔ 1102475519555507216: 79
#
# Duplicates in Manchester 024C:
#  - id=797725028342110636 | lat=53.455761 | lon=-2.241961 | snippet='Warm and cosy four bedroom house hosted by Staycasa Accommodation.<br />The house is located close t'
#  - id=891819532602187698 | lat=53.4557897 | lon=-2.2419023 | snippet='Warm and cosy one bedroom in a shared house hosted by Staycasa Accommodation.<br /><br />The house i'
#   Reasons (pairwise similarity scores):
#     797725028342110636 ↔ 891819532602187698: 97
#
# Duplicates in Manchester 024C:
#  - id=1073824073560953997 | lat=53.4578733713884 | lon=-2.2419776334853334 | snippet='Welcome to our shared house in Manchester! Your private 1-bedroom sanctuary awaits, providing a blen'
#  - id=1075227411886111691 | lat=53.45760337777526 | lon=-2.242218809248289 | snippet='Welcome to our ensuite in Manchester! Your private 1-bedroom sanctuary awaits, providing a blend of '
#   Reasons (pairwise similarity scores):
#     1073824073560953997 ↔ 1075227411886111691: 96
#
# Duplicates in Manchester 025A:
#  - id=1297782525686210557 | lat=53.4507423 | lon=-2.2338832 | snippet='Spacious Modern Home in Central Rusholme<br /><br />Relax in this bright, spacious 3-bedroom house i'
#  - id=1298047249402403099 | lat=53.45032398755758 | lon=-2.23115036714934 | snippet='Spacious Modern Home in Central Rusholme<br /><br />Relax in this bright, spacious 3-bedroom house i'
#   Reasons (pairwise similarity scores):
#     1297782525686210557 ↔ 1298047249402403099: 100
#
# Duplicates in Manchester 025B:
#  - id=1120186954525589629 | lat=53.45410246175253 | lon=-2.2377039341607423 | snippet='Welcome to our charming home in Manchester! Located in a vibrant neighborhood, our house is perfect '
#  - id=1213027664058807145 | lat=53.45371 | lon=-2.23823 | snippet='Welcome to our charming shared home with private room (en-suite) in Greater Manchester! Located in a'
#   Reasons (pairwise similarity scores):
#     1120186954525589629 ↔ 1213027664058807145: 76
#
# Duplicates in Manchester 025B:
#  - id=1282990077702892488 | lat=53.4512778 | lon=-2.2322837 | snippet='Relax at this peaceful place to stay, a home away from home<br /><br />𝟑 Bed Delux House in Manchest'
#  - id=1315759823761876043 | lat=53.45246020288998 | lon=-2.232756935145618 | snippet='Relax at this peaceful place to stay, a home away from home<br /><br />𝟑 Bed Delux House in Manchest'
#   Reasons (pairwise similarity scores):
#     1282990077702892488 ↔ 1315759823761876043: 100
#
# Duplicates in Manchester 025C:
#  - id=45695974 | lat=53.45784 | lon=-2.23155 | snippet='Gorgeous fully furnished house with equipped eat-in kitchen, lounge, bedrooms and bathrooms. Very cl'
#  - id=635951804886155164 | lat=53.45736 | lon=-2.23251 | snippet='Gorgeous fully furnished house with equipped eat-in kitchen, lounge, bedrooms and bathrooms. Very cl'
#  - id=661708388237910322 | lat=53.45711 | lon=-2.23184 | snippet='Gorgeous fully furnished house with equipped eat in kitchen, lounge, bedrooms and bathrooms. <br /><'
#  - id=869401917474398304 | lat=53.45762 | lon=-2.23323 | snippet='Gorgeous fully furnished house with equipped eat-in kitchen, lounge, bedrooms and bathrooms. <br /><'
#   Reasons (pairwise similarity scores):
#     45695974 ↔ 635951804886155164: 98
#     45695974 ↔ 661708388237910322: 96
#     45695974 ↔ 869401917474398304: 78
#     635951804886155164 ↔ 661708388237910322: 97
#     635951804886155164 ↔ 869401917474398304: 79
#
# Duplicates in Manchester 025C:
#  - id=51742758 | lat=53.45641 | lon=-2.22613 | snippet='This is a family friendly apartment block with 24-hour security.  Located on the lively and vibrant '
#  - id=51810232 | lat=53.45647 | lon=-2.22647 | snippet='This is a family friendly apartment block with 24-hour security.  Located on the lively and vibrant '
#   Reasons (pairwise similarity scores):
#     51742758 ↔ 51810232: 94
#
# Duplicates in Manchester 025C:
#  - id=19538607 | lat=53.45787 | lon=-2.2314 | snippet='hi <br />we have these large double rooms in our house . The house is situated on oxford road  very '
#  - id=37982211 | lat=53.45662 | lon=-2.22998 | snippet='hi <br />we have this double rooms in our house . The house is situated on oxford road  very close t'
#   Reasons (pairwise similarity scores):
#     19538607 ↔ 37982211: 84
#
# Duplicates in Manchester 025C:
#  - id=1176016005340002761 | lat=53.45778151938149 | lon=-2.232615279644323 | snippet='Centrally-located, less than a mile to Manchester University, museum, Royal Infirmary hospital and c'
#  - id=1297498191226919585 | lat=53.45610795753065 | lon=-2.231039436617289 | snippet='Kick back and relax in this calm, stylish room. Centrally-located, less than a mile to Manchester of'
#   Reasons (pairwise similarity scores):
#     1176016005340002761 ↔ 1297498191226919585: 77
#
# Duplicates in Manchester 025D:
#  - id=36601400 | lat=53.45218 | lon=-2.22954 | snippet='My place is very cosy, clean and quiet. It's a big room with a single bed with all the amenities. It'
#  - id=36916048 | lat=53.45321 | lon=-2.22977 | snippet='My place is very cozy, clean, and quiet. It's a small room with a single bed with all the amenities.'
#   Reasons (pairwise similarity scores):
#     36601400 ↔ 36916048: 95
#
# Duplicates in Manchester 025D:
#  - id=1264637135494416020 | lat=53.45372825048534 | lon=-2.2294561263772765 | snippet='“Cozy and Convenient Stay for All Travelers”<br /><br />Welcome to your perfect home away from home!'
#  - id=1292068872389105509 | lat=53.45229914527026 | lon=-2.2296360485723143 | snippet='“Cozy and Convenient Stay for All Travelers”<br /><br />Welcome to your perfect home away from home!'
#   Reasons (pairwise similarity scores):
#     1264637135494416020 ↔ 1292068872389105509: 97
#
# Duplicates in Manchester 025E:
#  - id=13735484 | lat=53.45504 | lon=-2.22296 | snippet='With close proximity to most amenities in the city of Manchester. On the same road as The University'
#  - id=15633409 | lat=53.45312 | lon=-2.22458 | snippet='With close proximity to most amenities in the city of Manchester. On the same road as The University'
#   Reasons (pairwise similarity scores):
#     13735484 ↔ 15633409: 81
#
# Duplicates in Manchester 025E:
#  - id=32286164 | lat=53.45616 | lon=-2.2251 | snippet='Newly refurbished room located in Manchester's famous "curry mile ". Each room is fully furnished an'
#  - id=32286614 | lat=53.45623 | lon=-2.22452 | snippet='Newly refurbished room located in Manchester's famous "curry mile ". Each room is fully furnished an'
# ...
#     825440276877551708 ↔ 836789824087697807: 94
#     825440276877551708 ↔ 925108814363137134: 82
#     825440276877551708 ↔ 937615836466711481: 98
#     836789824087697807 ↔ 925108814363137134: 81
#     836789824087697807 ↔ 937615836466711481: 92
#
# Duplicates in Trafford 004D:
#  - id=841322448125413159 | lat=53.45996 | lon=-2.276284 | snippet='Telly Homes Limited – Zinnia Unit Old Trafford, Manchester is decorated to the high-end standards an'
#  - id=841358298004804081 | lat=53.46093 | lon=-2.27746 | snippet='Kick back and relax in this calm, stylish space.<br />Telly Homes Limited – Zinnia Unit Old Trafford'
#   Reasons (pairwise similarity scores):
#     841322448125413159 ↔ 841358298004804081: 77
#
# Duplicates in Trafford 004D:
#  - id=991244319378309270 | lat=53.45876697137404 | lon=-2.2851862216349668 | snippet='This lovely 1 bedroom apartment is set within a modern development in the Old Trafford area of Manch'
#  - id=1000540837705460051 | lat=53.4588122738168 | lon=-2.284592942964007 | snippet='This cosy studio apartment is set within a modern development in the Old Trafford area of Manchester'
#  - id=1006422563567169117 | lat=53.45866189244768 | lon=-2.285262807911295 | snippet='This smart 1 bedroom apartment (ground floor) is set within a modern development in Old Trafford, Ma'
#  - id=1009351522999025873 | lat=53.45871595356436 | lon=-2.2858414368980795 | snippet='This lovely 1 bedroom apartment is set within a modern development in the Old Trafford area of Manch'
#  - id=1011332431217417502 | lat=53.45820419861175 | lon=-2.285158186972126 | snippet='This bright and modern 1 bedroom flat is set within a new development in Old Trafford, Manchester, j'
#  - id=1019379649759906953 | lat=53.45826 | lon=-2.28489 | snippet='This stylish 1 bedroom apartment is part of a modern development in the Old Trafford area of Manches'
#  - id=1023881096603143612 | lat=53.45835642793021 | lon=-2.286243997161673 | snippet='This modern 2 bedroom apartment is set within a contemporary development in the Old Trafford area of'
#  - id=1023881344469331991 | lat=53.458405703919 | lon=-2.284961002705502 | snippet='This bright and spacious 2 bedroom apartment is set within a contemporary development in the Old Tra'
#  - id=1023911953034027877 | lat=53.45876503905292 | lon=-2.284690769689856 | snippet='This bright and spacious 2 bedroom apartment is set within a new development in Old Trafford, Manche'
#  - id=1035413662429548746 | lat=53.45893804382179 | lon=-2.2845303058211406 | snippet='This lovely studio apartment set within a modern development in the Old Trafford area of Manchester,'
#  - id=1061417935201495025 | lat=53.4581915358024 | lon=-2.2860726453250653 | snippet='This bright and spacious 1 bedroom apartment is set within a modern development in the Old Trafford '
#  - id=1074450274662691087 | lat=53.45821719276378 | lon=-2.2843011106290434 | snippet='This modern 2 bedroom apartment is set on a high floor within a contemporary development in the Old '
#  - id=1086087269257528137 | lat=53.458336070970574 | lon=-2.2858955445806703 | snippet='This cosy studio apartment is set within a modern development in the Old Trafford area of Manchester'
#  - id=1094851433992217768 | lat=53.45820585804327 | lon=-2.285144108407429 | snippet='This modern and luxurious 1 bedroom apartment is set within a contemporary development in Old Traffo'
#  - id=1111426915319334049 | lat=53.45852 | lon=-2.2859 | snippet='This spacious and bright 1 bedroom apartment (ground floor) is set within a modern development in Ol'
#  - id=1121552721379537828 | lat=53.45822768392217 | lon=-2.286505858140371 | snippet='This convenient studio apartment is set within a modern development in the Old Trafford area of Manc'
#   Reasons (pairwise similarity scores):
#     991244319378309270 ↔ 1009351522999025873: 97
#     991244319378309270 ↔ 1121552721379537828: 94
#     1000540837705460051 ↔ 1009351522999025873: 91
#     1000540837705460051 ↔ 1011332431217417502: 91
#     1000540837705460051 ↔ 1019379649759906953: 91
#     1000540837705460051 ↔ 1023881096603143612: 92
#     1000540837705460051 ↔ 1023881344469331991: 91
#     1000540837705460051 ↔ 1023911953034027877: 91
#     1000540837705460051 ↔ 1061417935201495025: 93
#     1000540837705460051 ↔ 1074450274662691087: 91
#     1000540837705460051 ↔ 1086087269257528137: 99
#     1000540837705460051 ↔ 1094851433992217768: 90
#     1000540837705460051 ↔ 1121552721379537828: 89
#     1006422563567169117 ↔ 1023911953034027877: 90
#     1006422563567169117 ↔ 1111426915319334049: 98
#     1009351522999025873 ↔ 1121552721379537828: 94
#     1011332431217417502 ↔ 1023911953034027877: 97
#     1019379649759906953 ↔ 1023911953034027877: 90
#     1019379649759906953 ↔ 1094851433992217768: 92
#     1023881096603143612 ↔ 1023881344469331991: 98
#     1023881096603143612 ↔ 1023911953034027877: 96
#     1023881096603143612 ↔ 1074450274662691087: 99
#     1023881344469331991 ↔ 1023911953034027877: 97
#     1035413662429548746 ↔ 1121552721379537828: 91
#     1061417935201495025 ↔ 1074450274662691087: 90
#     1086087269257528137 ↔ 1094851433992217768: 91
#     1086087269257528137 ↔ 1121552721379537828: 90
#
# Duplicates in Trafford 004D:
#  - id=1002013619218348363 | lat=53.45865 | lon=-2.28568 | snippet='This one-bedroom apartment in Old Trafford is perfect for couples looking to stay in the city centre'
#  - id=1005510941500310726 | lat=53.45972632112318 | lon=-2.283085995814257 | snippet='This studio apartment in Old Trafford is perfect for couples looking to stay in the city centre. It '
#   Reasons (pairwise similarity scores):
#     1002013619218348363 ↔ 1005510941500310726: 98
#
# Duplicates in Trafford 006B:
#  - id=560996032749789109 | lat=53.47079 | lon=-2.29881 | snippet='This is a premium apartment in the creative media hub of media city. This unique place has a style a'
#  - id=562461078073791304 | lat=53.47087 | lon=-2.30077 | snippet='This is a premium apartment in the creative media hub of media city. This unique place has a style a'
#   Reasons (pairwise similarity scores):
#     560996032749789109 ↔ 562461078073791304: 81
#
# Duplicates in Trafford 006B:
#  - id=1210337770642339752 | lat=53.46643 | lon=-2.28788 | snippet='Perfect for work or social trips.<br />Communal cinema room, meeting/break rooms<br />Great location'
#  - id=1210679470241842665 | lat=53.46617 | lon=-2.28674 | snippet='Perfect for work or social trips.<br />Communal cinema room, meeting/break<br />rooms<br />Great loc'
#   Reasons (pairwise similarity scores):
#     1210337770642339752 ↔ 1210679470241842665: 96
#
# Duplicates in Trafford 009A:
#  - id=1134717161693531181 | lat=53.45062027576391 | lon=-2.349105480184892 | snippet='This typical English Victorian townhouse has lovely living areas/ bedrooms across 4 floors. I have a'
#  - id=1134732621264313775 | lat=53.45178 | lon=-2.34943 | snippet='This clean, spacious Victorian townhouse has lovely rooms and attractive living areas .I have a hot '
#   Reasons (pairwise similarity scores):
#     1134717161693531181 ↔ 1134732621264313775: 77
#
# Duplicates in Trafford 015B:
#  - id=735431623074258754 | lat=53.425694263589 | lon=-2.320583419785908 | snippet='This recently converted property in the heart of Sale, Greater Manchester provide a fantastic base w'
#  - id=735433602507693230 | lat=53.42570206770617 | lon=-2.3200926140223936 | snippet='These recently converted apartments in the heart of Sale, Greater Manchester provide a fantastic bas'
#   Reasons (pairwise similarity scores):
#     735431623074258754 ↔ 735433602507693230: 83
#
# Duplicates in Trafford 015C:
#  - id=730473788516476045 | lat=53.424087952842896 | lon=-2.315838038921356 | snippet='Enjoy a stylish experience at this centrally-located place. Guests will enjoy easy access to Bars, R'
#  - id=888197517688081021 | lat=53.4235364 | lon=-2.3144526 | snippet='Enjoy a stylish experience at this centrally-located place. Guests will enjoy easy access to Bars, R'
#   Reasons (pairwise similarity scores):
#     730473788516476045 ↔ 888197517688081021: 78
#
# Duplicates in Trafford 024D:
#  - id=1065938613804830075 | lat=53.39162117509792 | lon=-2.3434367436548094 | snippet='Perfect for short term stays and long term stays I Mid Week Group Stays | Contractors I Families<br '
#  - id=1065975504705862304 | lat=53.393023293597565 | lon=-2.3418286915937654 | snippet='28+ Night Stay - Bills are not included . We offer bills for £500 additional a month.<br /><br />Per'
#   Reasons (pairwise similarity scores):
#     1065938613804830075 ↔ 1065975504705862304: 79
#
# Duplicates in Trafford 024E:
#  - id=1109461624550970575 | lat=53.38448560717313 | lon=-2.340432693553231 | snippet='A beautifully presented capacious double bedroom with ensuite in popular area of Altrincham. This pr'
#  - id=1112353412494563159 | lat=53.38482 | lon=-2.34072 | snippet='A beautifully presented capacious double bedroom in popular area of Altrincham. This property is in '
#   Reasons (pairwise similarity scores):
#     1109461624550970575 ↔ 1112353412494563159: 86
#
# Duplicates in Trafford 025B:
#  - id=1008735603011453520 | lat=53.38887 | lon=-2.35086 | snippet='The apartment includes 2 king size bedrooms, fully fitted kitchen with open plan lounge & beautiful '
#  - id=1008764053210061138 | lat=53.3879802038546 | lon=-2.3512455344587653 | snippet='Comprising 2 king size bedrooms, fully fitted kitchen with open plan lounge & beautiful stained glas'
#   Reasons (pairwise similarity scores):
#     1008735603011453520 ↔ 1008764053210061138: 80
#
# Duplicates in Trafford 025B:
#  - id=1159234014687703011 | lat=53.38576 | lon=-2.34963 | snippet='MANAGED BY PASS THE KEYS® SOUTH MANCHESTER<br /><br />This lovely 2 bed apartment sleeps up to 3 gue'
#  - id=1159239931440555696 | lat=53.38686690590215 | lon=-2.349519603167247 | snippet='MANAGED BY PASS THE KEYS® SOUTH MANCHESTER<br /><br />This stylish and well located 2 bed apartment '
#   Reasons (pairwise similarity scores):
#     1159234014687703011 ↔ 1159239931440555696: 99
#
# Duplicates in Trafford 025C:
#  - id=1151999871420669170 | lat=53.38343673664488 | lon=-2.3522767832639686 | snippet='MANAGED BY PASS THE KEYS® SOUTH MANCHESTER<br /><br />This modern and stylish 2 bed apartment is won'
#  - id=1152017757875851316 | lat=53.38373 | lon=-2.35169 | snippet='MANAGED BY PASS THE KEYS® SOUTH MANCHESTER<br /><br />This stylish and centrally located 2 bed apart'
#  - id=1159222176531611710 | lat=53.383699967577954 | lon=-2.350493565065394 | snippet='MANAGED BY PASS THE KEYS® SOUTH MANCHESTER<br /><br />This stylish 2 bed apartment sleeps up to 4 gu'
#  - id=1159229845252190488 | lat=53.384511557962576 | lon=-2.350504453869735 | snippet='MANAGED BY PASS THE KEYS® SOUTH MANCHESTER<br /><br />This stylish 2 bed apartment sleeps up to 4 gu'
#   Reasons (pairwise similarity scores):
#     1151999871420669170 ↔ 1152017757875851316: 91
#     1151999871420669170 ↔ 1159222176531611710: 92
#     1151999871420669170 ↔ 1159229845252190488: 88
#     1152017757875851316 ↔ 1159222176531611710: 98
#     1152017757875851316 ↔ 1159229845252190488: 94
#     1159222176531611710 ↔ 1159229845252190488: 95
#
# Duplicates in Trafford 026A:
#  - id=25761044 | lat=53.37661 | lon=-2.33943 | snippet='Our place is close to public transport, Manchester Airport, Altrincham town centre, restaurants and '
#  - id=28233032 | lat=53.37791 | lon=-2.33945 | snippet='Our place is close to public transport, Manchester Airport, Altrincham town centre, restaurants and '
#  - id=31877635 | lat=53.37858 | lon=-2.3379 | snippet='Our place is close to public transport, Manchester Airport, Altrincham town centre, restaurants and '
#   Reasons (pairwise similarity scores):
#     25761044 ↔ 28233032: 99
#     25761044 ↔ 31877635: 98
#     28233032 ↔ 31877635: 99
#
# Duplicates in Trafford 028A:
#  - id=2053538 | lat=53.36784 | lon=-2.32991 | snippet='Halliwell house is an exclusive private residence . Offering secure very private accommodation .Five'
#  - id=34566723 | lat=53.36786 | lon=-2.32983 | snippet='Halliwell house is an exclusive private residence . Offering secure very private accommodation .Five'
#   Reasons (pairwise similarity scores):
#     2053538 ↔ 34566723: 80
#
# Duplicates in Trafford 028C:
#  - id=37581000 | lat=53.36394 | lon=-2.30775 | snippet='500 Yards from the M56 Motorway and within walking distance to Hale Barns and Hale Village which has'
#  - id=37582424 | lat=53.36313 | lon=-2.30769 | snippet='Close to the M56 Motorway  and within walking distance to Hale Barns and Hale Village where there ar'
#   Reasons (pairwise similarity scores):
#     37581000 ↔ 37582424: 87
#
# Duplicates in Wigan 012B:
#  - id=26189302 | lat=53.54285 | lon=-2.60827 | snippet='A quiet, clean, newly refurbished 4 bedroom house, with modern kitchen/dinning room, 3 piece bathroo'
#  - id=26413914 | lat=53.54232 | lon=-2.60748 | snippet='A quiet, clean, newly refurbished 4 bedroom house, with modern kitchen/dinning room, 3 piece bathroo'
#  - id=51690260 | lat=53.5424 | lon=-2.60642 | snippet='A quiet, clean, newly refurbished 4 bedroom house, with modern kitchen/dinning room, 3 piece bathroo'
#   Reasons (pairwise similarity scores):
#     26189302 ↔ 26413914: 79
#     26189302 ↔ 51690260: 85
#     26413914 ↔ 51690260: 75
#
# Duplicates in Wigan 015A:
#  - id=993462506862988327 | lat=53.54303541260627 | lon=-2.6392917342544564 | snippet='Modern  2-Bed Apartments | Free Wi-Fi | Central | NEW<br /><br />These 2-Bedroom apartments in the h'
#  - id=993470200446946354 | lat=53.54295253393119 | lon=-2.639157623803712 | snippet='Modern  1-Bed Apartments | Free Wi-Fi | Central | NEW<br /><br />This 1-Bedroom apartment in the hea'
#   Reasons (pairwise similarity scores):
#     993462506862988327 ↔ 993470200446946354: 99
#
# Duplicates in Wigan 018B:
#  - id=1094383037801105495 | lat=53.54044953230725 | lon=-2.702082967955972 | snippet='Explore this newly renovated complex, featuring four spacious blocks of flats perfect for both contr'
#  - id=1094401844529493935 | lat=53.53817 | lon=-2.70052 | snippet='Explore this newly renovated complex, featuring four spacious blocks of flats perfect for both contr'
#  - id=1129804193058426870 | lat=53.54041 | lon=-2.70194 | snippet='Explore this newly renovated Apartment, perfect for both contractor's  corporate clients and familie'
#   Reasons (pairwise similarity scores):
#     1094383037801105495 ↔ 1094401844529493935: 81
#     1094401844529493935 ↔ 1129804193058426870: 81
#
# Duplicates in Wigan 018C:
#  - id=888363938110018867 | lat=53.53608 | lon=-2.70824 | snippet='Detached town house in Wigan with off road private parking. Located just off the M6 motorway this pr'
#  - id=889513292704624098 | lat=53.53516 | lon=-2.70833 | snippet='Detached town house in Wigan with off road private parking. Located just off the M6 motorway this pr'
#   Reasons (pairwise similarity scores):
#     888363938110018867 ↔ 889513292704624098: 82
#
# Duplicates in Wigan 027C:
#  - id=6689776 | lat=53.51416 | lon=-2.53372 | snippet='Cosy well equipped room in a bright and airy 3 bed house in a quiet cul-de-sac.<br /><br />Room is s'
#  - id=21497673 | lat=53.51418 | lon=-2.53347 | snippet='Cosy well equipped twin room in a very clean and bright 3 bed house in a quiet cul-de-sac.<br /><br '
#   Reasons (pairwise similarity scores):
#     6689776 ↔ 21497673: 90
#
# Duplicates in Wigan 035A:
#  - id=1164404280781446498 | lat=53.49608509999999 | lon=-2.6223872 | snippet='Asher House is a stylish and newly refurbished 3 bedroom house which boasts a spacious living room, '
#  - id=1195512896169377619 | lat=53.4962636 | lon=-2.62244 | snippet='Enjoy a blissful stay at our stylish 3 bedroom 2 bathroom house featuring a spacious living room, a '
#   Reasons (pairwise similarity scores):
#     1164404280781446498 ↔ 1195512896169377619: 78
#
# Duplicates in Wigan 036E:
#  - id=16531283 | lat=53.48786 | lon=-2.64261 | snippet='A clean & comfortable double room in an end of terraced Victorian villa.<br />1 Yorkshire terrier an'
#  - id=16539465 | lat=53.48953 | lon=-2.64406 | snippet='A clean & comfortable single room in an end of terraced Victorian villa.<br />1 small Yorkshire terr'
#   Reasons (pairwise similarity scores):
#     16531283 ↔ 16539465: 91
# 7460

# %% [markdown]
# ### Count the number of listings in each LSOA

# %%
# # Find the most common score in each LSOA
# count = pd.DataFrame({'Count' : deduplicated_listings.groupby("LSOA11NM").size()})
# count.reset_index(inplace=True)
# # count_filtered = count[count >8]
# count_filtered=count
# central_lsoas = central_lsoas.sort_values(by='LSOA11NM')
# central_lsoas = central_lsoas.merge(count_filtered, on='LSOA11NM', how='left')

# %% [markdown]
# ### Filter to only keep LSOAs within a 6000m buffer zone of the centre of Manchester

# %%
fig, axs = plt.subplots(ncols=2, figsize=(8, 5), sharey=True)

central_lsoas.plot(ax=axs[0], color='lightgrey', edgecolor='black')
axs[0].set_title("All")

vmin = central_lsoas['Count'].min()
vmax = central_lsoas['Count'].max()
cmap = 'viridis'
central_lsoas.plot(column='Count', ax=axs[1], cmap=cmap, vmin=vmin, vmax=vmax, legend=False)
axs[1].set_title("Count")

# Build a ScalarMappable for the colorbar
sm = mpl.cm.ScalarMappable(cmap=cmap, norm=mpl.colors.Normalize(vmin=vmin, vmax=vmax))
sm._A = []

# Use the second axes' position to create a colorbar axis with identical height
pos = axs[1].get_position()  # Bbox: x0, y0, width, height in figure coords
cax = fig.add_axes([pos.x1 + 0.01, pos.y0, 0.02, pos.height])  # [left, bottom, width, height]
cbar = fig.colorbar(sm, cax=cax)
cbar.ax.tick_params(labelsize=8)

# %% [markdown]
# ### Keep only those in the central LSOAs

# %%
# unique_listings_gdf = unique_listings_gdf[unique_listings_gdf['LSOA11NM'].isin(central_lsoas['LSOA11NM'].unique())]
# del unique_listings_gdf['geometry']

# %% [markdown]
# ## The prompt

# %%
prompt_explanatory = f"""
You are an expert in urban studies with a deep understanding of gentrification and its portrayal in public discourse. I will provide you with Airbnb 
listings, including a description of the property and a neighborhood overview. Your task is to analyze these texts and assess the gentrification status 
of the area based on how the neighborhood is presented.

Focus primarily on the neighborhood overview and description, ignoring property-specific details like the number of bedrooms, amenities, or decor. 

Consider the following:
- Direct mentions of local attractions, businesses, or community features that suggest development or revitalization.
- Language that highlights cultural hotspots, boutique shops, trendy cafes, or artisanal markets.
- Descriptions that emphasize diversity, safety, or the presence of creative communities, as these can signal gentrification dynamics.
- Listings that avoid mentioning the neighborhood or speak only broadly about the city may imply that the immediate area lacks desirable features or is 
not a selling point. This absence of detail should inform your assessment.

Assign one of the following categories:
- "Established": A well-known, desirable area with stable appeal and little active change.
- "Gentrifying": Signs of recent or ongoing transformation, such as new businesses or cultural shifts.
- "Emerging": Early indicators of gentrification potential, like creative spaces or gradual commercial interest.
- "Undeveloped": Lacking indicators of gentrification, often reflected in vague or absent neighborhood descriptions.

If a listing genuinely lacks sufficient information to make any assessment (e.g., the text is too sparse), assign a score of 'NA' and briefly explain.

Provide your answer strictly in the format:
'1. Category. Reasoning.', '2. Category. Reasoning.', etc., without any additional explanation or commentary.
"""
prompt = prompt_explanatory

# %% [markdown]
# ## Decide whether to run LLM
# Decide whether to run the LLM or load a file of scores that has been previously calculated and saved

# %%
# Check for existing files
base_dir = os.path.expanduser(f"../../../data/AirbnbData/airbnb-{city}/")
base_filename = "airbnb_gentrification_scores_new"
file_extension = ".gpkg"

# List all matching files in the directory
matching_files = [
    f for f in sorted(os.listdir(base_dir))
    if re.match(f"{base_filename}_\\d{{2}}{file_extension}$", f)]
matching_files
# Out:
# []

# %%
# If there are matching files, find the most recent one
if matching_files:
    df = gpd.read_file(base_dir+matching_files[-1])
    print(f"Loaded file: {matching_files[-1]}")
else:
    # If no matching files are found
    print("No matching files found. 'df' will not be loaded.")
    df = None
# Out:
# No matching files found. 'df' will not be loaded.

# %%
RUN_LLM = True
if df is not None:
    print("Have already loaded a gentrification file, will not re-run the LLM.")
    RUN_LLM = False

RUN_LLM = True  # Optionally override

if RUN_LLM:
    print("Running LLM")
    # Get the API key from a file
    with open('../together.ai_key.txt', 'r') as f:
        api_key = f.readline().strip()

    client = Together(api_key=api_key)

    # Sample for now?
    # df = final_listings.sample(20).copy()
    df = deduplicated_listings.copy()

    print(f"Will query the LM for {len(df)} items")

    assert len(df) < 11000, "Too many tweets to process in one go. Please reduce the number of tweets."

    # Ensure the index is consecutive and ascending
    df = df.reset_index(drop=True)
    # To store the results
    df['gentrification_prediction'] = None

    # Batch processing
    batch_size = 20
    for i in range(0, len(df), batch_size):
        # Get the batch of tweets
        batch_tweets = df.loc[i:i + batch_size - 1, :]

        # Get sentiments using the function
        print(f"Submitting batch {i//len(batch_tweets)+1} of {len(df)//len(batch_tweets)}...")

        ids, sentiments, explanations = get_gentrification_scores_categorical(
            batch_tweets, prompt, client, batch_index=i, max_tokens=1500)
        # Update the DataFrame with the predictions
        df.loc[ids, 'gentrification_prediction'] = sentiments
        df.loc[ids, 'explanation'] = explanations

        # Predictions should be integers
        # df.gentrification_prediction = df.gentrification_prediction.astype('Int64')

    print("Finished querying LLM. Now saving file")

    # Initialize counter and check for existing files
    counter = 1
    while True:
        filename = f"{base_filename}_{counter:02d}.csv"
        filepath = os.path.join(base_dir, filename)
        if not os.path.exists(filepath):
            break
        counter += 1
    df.to_csv(f"{filepath}")    
    # df.set_crs(epsg=4326, inplace=True)
    # df.to_file(filepath, layer="data", driver="GPKG")
    print(f"File saved as: {filepath}")
# Out:
# Running LLM
# Will query the LM for 6323 items
# Submitting batch 1 of 316...
# 1. Emerging. The neighborhood is described as a quiet hamlet with good access to main roads and motorways, and nearby country parks, suggesting a peaceful area with potential for exploration.
# 1
# 2. Established. The area is described as a comfortable base for visiting the North of England, with numerous walks, bike rides, and restaurants nearby, indicating a well-developed and desirable location.
# 2
# 3. Emerging. The neighborhood is described as quiet and safe, with a good selection of restaurants and pubs, and nearby country parks, suggesting a peaceful area with some amenities.
# 3
# 4. Gentrifying. The village of Egerton is described as quaint, with independent bistros, award-winning tea rooms, and fantastic pubs, indicating a charming and upscale area with potential for further development.
# 4
# 5. Established. The area of Bradshaw is described as desirable, with a supermarket and other shops within walking distance, and nearby parks and golf courses, suggesting a well-developed and convenient location.
# 5
# 6. Established. The leafy suburb of Bradshaw is described as friendly, with a spacious and stylish home, and nearby attractions such as museums and country parks, indicating a well-developed and desirable location.
# 6
# 7. Emerging. The area is described as a quiet development with scenic views, shops, bars, and restaurants within walking distance, suggesting a peaceful and convenient location with potential for exploration.
# 7
# 8. Gentrifying. The area is described as quiet and friendly, with award-winning pubs, a spa, and brand new restaurants, indicating a charming and upscale area with potential for further development.
# 8
# 9. Established. The area of Eagley Bank is described as peaceful and quaint, with a beautiful garden, and nearby train stations with direct links to Manchester, suggesting a well-developed and desirable location.
# 9
# 10. NA. The listing lacks sufficient information to assess the gentrification status of the area.
# 10
# 11. NA. The listing lacks sufficient information to assess the gentrification status of the area.
# 11
# 12. NA. The listing lacks sufficient information to assess the gentrification status of the area.
# 12
# 13. Emerging. The area is described as having great transport links to Manchester, and nearby supermarkets and shops, suggesting a convenient location with potential for exploration.
# 13
# 14. Emerging. The area is described as private but not far from amazing restaurants, and close to Bolton and Greater Manchester, suggesting a peaceful and convenient location with potential for exploration.
# 14
# 15. Established. The area is described as calm and stylish, with all local amenities within easy reach, and close to Bolton town centre and the countryside, indicating a well-developed and desirable location.
# 15
# 16. Emerging. The area of Bromley Cross is described as close to local amenities and public transport, with frequent buses and a direct train link to Manchester, suggesting a convenient location with potential for exploration.
# 16
# 17. Gentrifying. The area of Bromley Cross is described as having a brand new and newly renovated property, with space and stylish amenities, indicating a charming and upscale area with potential for further development.
# 17
# 18. Gentrifying. The area is described as having the best of both worlds, with a modern and newly refurbished home, and nearby award-winning pubs, a spa, and brand new restaurants, indicating a charming and upscale area with potential for further development.
# 18
# 19. Emerging. The area of Horwich is described as having a short walk into the town centre, and nearby bus stops and train stations, suggesting a convenient location with potential for exploration.
# 19
# 20. Emerging. The area of Horwich is described as having everything you need within walking distance, and nearby bus stops and train stations, suggesting a convenient location with potential for exploration.
# 20
# Submitting batch 2 of 316...
# 1. Emerging. The neighborhood description mentions a variety of places to eat and go out, as well as proximity to natural landscapes and a shopping center, indicating potential for gentrification.
# 1
# 2. Gentrifying. The text highlights the area's unique character, with eateries, real ale brewers, and live music, suggesting recent or ongoing transformation.
# 2
# 3. NA. The listing lacks sufficient information about the neighborhood to make an assessment.
# 3
# 4. Established. The description presents Horwich as a charming and vibrant town with a blend of tranquility and convenience, implying a well-known and desirable area.
# 4
# 5. Emerging. The mention of a rural setting, local nature reserve, and electric vehicle charging point suggests a potentially up-and-coming area.
# 5
# 6. Gentrifying. The text highlights Rivington's thriving local breweries and restaurants, as well as its natural beauty, indicating recent or ongoing transformation.
# 6
# 7. Emerging. The description emphasizes the area's natural beauty and potential for outdoor activities, suggesting a potentially up-and-coming area.
# 7
# 8. Established. The text presents Horwich as a vibrant and picturesque town with a range of amenities, implying a well-known and desirable area.
# 8
# 9. Emerging. The mention of a quiet location with access to pubs, restaurants, and a leisure center suggests a potentially up-and-coming area.
# 9
# 10. NA. The listing lacks sufficient information about the neighborhood to make an assessment.
# 10
# 11. Emerging. The text highlights the area's unique amenities, such as a cinema and curry restaurant, suggesting potential for gentrification.
# 11
# 12. Emerging. The mention of a gym, cinema, and restaurant within walking distance suggests a potentially up-and-coming area.
# 12
# 13. Undeveloped. The description focuses on the property's amenities and lacks detail about the neighborhood, implying a lack of desirable features.
# 13
# 14. Established. The text presents the neighborhood as tranquil and offering easy access to local attractions, implying a well-known and desirable area.
# 14
# 15. Undeveloped. The listing lacks sufficient information about the neighborhood to make an assessment.
# 15
# 16. Emerging. The mention of a rural setting and private land suggests a potentially up-and-coming area.
# 16
# 17. Emerging. The text highlights the area's rural walks and local amenities, such as a supermarket and butcher, suggesting potential for gentrification.
# 17
# 18. Emerging. The description emphasizes the area's semi-rural location and proximity to natural landscapes, as well as its convenience for traveling to nearby cities, suggesting potential for gentrification.
# 18
# 19. Emerging. The mention of a rural setting and luxurious amenities, such as super king beds and underfloor heating, suggests a potentially up-and-coming area.
# 19
# 20. Gentrifying. The text highlights the area's quirky character and proximity to shops, bars, and restaurants, indicating recent or ongoing transformation.
# 20
# Submitting batch 3 of 316...
# 1. Emerging. The neighborhood description mentions a shop on the corner and a retail park within walking distance, indicating some commercial development.
# 1
# 2. Established. The description highlights the town's vibrant atmosphere, independent shops, and various attractions, suggesting a well-developed area.
# 2
# 3. NA. The text is too sparse to make an assessment.
# 3
# 4. Established. The description portrays Horwich as a vibrant and picturesque town with a stadium and retail park, indicating a stable and desirable area.
# 4
# 5. Emerging. The listing mentions several nearby attractions and a beautiful town, but the description is brief and lacks specific details about the neighborhood.
# 5
# 6. Gentrifying. The text describes the area as vibrant and lively, with shops and amenities within walking distance, suggesting recent or ongoing transformation.
# 6
# 7. Established. The description emphasizes the peaceful and plentiful environment, with shops and restaurants within walking distance, indicating a well-developed area.
# 7
# 8. Established. The description is similar to listing 4, portraying Horwich as a vibrant and picturesque town with a stadium and retail park.
# 8
# 9. Undeveloped. The listing lacks specific details about the neighborhood, instead focusing on the city's general location and transport links.
# 9
# 10. NA. The text is too sparse to make an assessment.
# 10
# 11. Emerging. The description mentions several nearby attractions and shopping centers, but the focus is on the property's amenities rather than the neighborhood.
# 11
# 12. Gentrifying. The text expresses a desire to share the town's offerings, suggesting a sense of pride and investment in the area's development.
# 12
# 13. Emerging. The listing mentions nearby country walks and a retail park, but the description is brief and lacks specific details about the neighborhood.
# 13
# 14. Emerging. The description highlights the beautiful countryside and outdoor activities, but the focus is on the property's amenities rather than the neighborhood.
# 14
# 15. NA. The text lacks specific details about the neighborhood.
# 15
# 16. Undeveloped. The listing lacks specific details about the neighborhood, instead focusing on the property's general location and amenities.
# 16
# 17. Undeveloped. The description mentions a private new build estate, but lacks specific details about the surrounding neighborhood.
# 17
# 18. NA. The text lacks specific details about the neighborhood.
# 18
# 19. Established. The description portrays the property as a stunning and elegant home, but lacks specific details about the neighborhood.
# 19
# 20. Emerging. The listing mentions nearby shopping centers and a train stop, but the description is brief and lacks specific details about the neighborhood.
# 20
# Submitting batch 4 of 316...
# 1. Emerging. The mention of a "newly built housing estate" and "great transport links" suggests some level of development or investment in the area.
# 1
# 2. Established. The description of the neighborhood as "quiet" and the presence of a town center and easy access to Manchester city suggest a stable and desirable area.
# 2
# 3. Undeveloped. The lack of detail about the neighborhood, with only a mention of a train station, does not provide enough information to assess gentrification.
# 3
# 4. NA. The listing focuses on property-specific details and does not provide any information about the neighborhood.
# 4
# 5. Established. The mention of a town center, countryside, and local shops suggests a stable and desirable area with existing amenities.
# 5
# 6. Emerging. The proximity to a country park and Bolton center, as well as the description of the area as "cosy", may indicate some level of gentrification potential.
# 6
# 7. Gentrifying. The presence of "boutique" apartments, a shopping park, and a museum suggests some level of development and cultural shift in the area.
# 7
# 8. Gentrifying. Similar to listing 7, the mention of "boutique" apartments, a train station, and local attractions like a museum and arena indicates ongoing transformation.
# 8
# 9. Gentrifying. The presence of a "popular restaurant" and "quite a few take aways" suggests some level of commercial interest and cultural activity in the area.
# 9
# 10. NA. The listing focuses on property-specific details and does not provide enough information about the neighborhood.
# 10
# 11. Undeveloped. The lack of detail about the neighborhood, with only a mention of a convenient store and bus stop, does not suggest any significant gentrification.
# 11
# 12. Established. The mention of a park, countryside views, and local shops suggests a stable and desirable area with existing amenities.
# 12
# 13. Gentrifying. The presence of "good quality pubs and restaurants" and "unique coffee shops" suggests some level of cultural and commercial development in the area.
# 13
# 14. Established. The mention of a park and a unique holiday experience suggests a stable and desirable area with existing amenities.
# 14
# 15. Emerging. The description of the area as having "fantastic links" to roads and motorways, as well as "stunning countryside", may indicate some level of gentrification potential.
# 15
# 16. Established. The mention of a "picturesque lodge" and "quaint country pubs" suggests a stable and desirable area with existing amenities.
# 16
# 17. Established. The description of the property as "modern" and "spacious" suggests a stable and desirable area with existing amenities.
# 17
# 18. Established. The mention of a "quiet residential area" with good access to cities and amenities suggests a stable and desirable area.
# 18
# 19. Undeveloped. The lack of detail about the neighborhood, with only a mention of proximity to town centers, does not provide enough information to assess gentrification.
# 19
# 20. NA. The listing focuses on property-specific details and does not provide any information about the neighborhood.
# 20
# Submitting batch 5 of 316...
# 1. Undeveloped. The listing lacks specific details about the neighborhood, focusing instead on the property's amenities and comfort, suggesting the area itself may not be a significant selling point.
# 1
#
# 2. Undeveloped. The description primarily discusses the property's features and its proximity to Bolton, without providing detailed information about the local neighborhood or its attractions.
# 2
#
# 3. Undeveloped. Similar to the previous listings, this one focuses on the convenience of the location for commuting and the property's features, without highlighting specific neighborhood attractions or characteristics.
# 3
#
# 4. Established. The mention of a retail park with restaurants, a cinema, and a variety of shops, along with a train station and motorway, indicates a well-developed area with amenities, suggesting an established neighborhood.
# 4
#
# 5. Established. The description of a quiet, tree-lined road, proximity to Bolton Wanderers stadium, and access to rail stations and Manchester Airport, paints a picture of a stable and desirable area.
# 5
#
# 6. Emerging. The emphasis on modern luxury, state-of-the-art appliances, and a dedicated cinema room suggests recent investment or renovation, which could be an early sign of gentrification.
# 6
#
# 7. Established. The presence of a retail park, a railway station, and a pristine golf course adjacent to the property indicates a well-developed and desirable area with stable appeal.
# 7
#
# 8. Gentrifying. The mention of a retail park, university, station, and town centre, along with the description of a renovated modern bathroom and communal spaces, suggests an area undergoing transformation or improvement.
# 8
#
# 9. Emerging. The brand new, fully refurbished property with top-spec furnishings and a lovely view could indicate early signs of gentrification, especially if similar developments are occurring in the surrounding area.
# 9
#
# 10. Established. The description of private parking, proximity to supermarkets, town centre, and a beautifully landscaped park suggests a well-developed and convenient neighborhood.
# 10
#
# 11. Gentrifying. The newly refurbished house with super fast fibre broadband, Dolce Gusto coffee, and smart TVs, located near bars, restaurants, and activities, indicates an area that is being revitalized or upgraded.
# 11
#
# 12. Undeveloped. The listing lacks detailed information about the neighborhood, focusing on the property's peaceful nature and shared living arrangements, which does not provide insight into the area's gentrification status.
# 12
#
# 13. Undeveloped. The description is too vague, mentioning only a "nice quiet neighborhood" without providing specific details about local attractions, businesses, or community features.
# 13
#
# 14. Gentrifying. The mention of a vibrant city centre, local retail parks, and several parks (like Queen's Park and Leverhulme Park) suggests an area with cultural and commercial activity, potentially undergoing gentrification.
# 14
#
# 15. Established. The modern home with smart TV and high-speed fibre optic broadband, located in the heart of Bolton with easy access to the town centre and Manchester, indicates a well-developed and desirable area.
# 15
#
# 16. Undeveloped. The listing is too sparse, lacking specific details about the neighborhood or its characteristics, making it difficult to assess the gentrification status.
# 16
#
# 17. Emerging. The description of a cozy, fresh, and clean terraced home in a quiet and safe area near Bolton private school, with amenities like free breakfast and reliable Wi-Fi, could suggest early signs of gentrification, especially with the mention of Bolton being dubbed one of the UK's friendliest towns.
# 17
#
# 18. Gentrifying. The newly decorated 5-bedroom house with excellent transport links, smart TVs, and a fully equipped kitchen, along with the proximity to the town centre and various amenities, indicates an area that is being developed or revitalized.
# 18
#
# 19. Established. The spacious private apartment in a quiet area yet close to Bolton town centre suggests a well-developed and convenient neighborhood with stable appeal.
# 19
#
# 20. Gentrifying. The chic accommodation with fashionable bedrooms, dedicated workspace, and inviting living space, located near the town center with easy access to Manchester and various amenities, indicates an area that is undergoing transformation or improvement.
# 20
# Submitting batch 6 of 316...
# 1. Undeveloped. The listing lacks any detailed description of the neighborhood, focusing solely on the property and its amenities.
# 1
# 2. Established. The neighborhood is described as the "heart of Bolton" with a "bustling town centre", indicating a well-known and desirable area.
# 2
# 3. Emerging. The mention of "surrounding eateries and amenities" and a "prime location" suggests some development, but the description is not overly elaborate, indicating potential for growth.
# 3
# 4. Undeveloped. The description focuses on the practical aspects of the location, such as proximity to the town centre and transport links, without highlighting any specific attractions or community features.
# 4
# 5. Gentrifying. The apartment is located "in the heart of Bolton Town Centre" with "a number of attractions, shops, restaurants and bars" nearby, suggesting recent or ongoing transformation.
# 5
# 6. Established. The area is described as "very quiet" and having a "shopping complex nearby" with known stores and a cinema, indicating a stable and desirable neighborhood.
# 6
# 7. Emerging. The room is "steps from Town Centre Shops & Dining", suggesting some level of development and convenience, but the description is brief and lacks detail.
# 7
# 8. Gentrifying. The apartment is located on a "lovely cobbled street" with "buildings from the 1600s" and is close to shops, restaurants, and bars, indicating a trendy and transforming area.
# 8
# 9. Established. The apartment is in "Bolton town centre, close to all the shops, restaurants and bars", suggesting a well-known and desirable location.
# 9
# 10. Undeveloped. The description is very brief and lacks any specific details about the neighborhood, focusing on the property's convenience and proximity to the city centre.
# 10
# 11. Gentrifying. The apartment is in the "heart of Bolton Town Centre" with "modern furnishings" and is close to the "famous Bolton Market" and other attractions, indicating a transforming and desirable area.
# 11
# 12. Established. The apartment is "perfectly located" for commuters and is close to the shopping centre, train station, and university, suggesting a stable and convenient neighborhood.
# 12
# 13. Emerging. The apartment is "close to all the important spots in the town" and is a "stone's throw from the train station", indicating some level of development and convenience.
# 13
# 14. Established. The flats are "centrally-located" and close to the train station, market, university, and amenities, suggesting a well-known and desirable area.
# 14
# 15. Gentrifying. The apartment is in a "charming and convenient location" with "historic landmarks", shops, restaurants, and cafes nearby, indicating a transforming and desirable area.
# 15
# 16. Established. The apartment is in "Bolton Town centre" with a "museum and shopping Center" nearby, suggesting a well-known and desirable location.
# 16
# 17. Undeveloped. The description focuses on the practical aspects of the location, such as proximity to the hospital and town centre, without highlighting any specific attractions or community features.
# 17
# 18. Undeveloped. The description is very brief and lacks any specific details about the neighborhood, focusing on the property's convenience and proximity to Manchester.
# 18
# 19. Gentrifying. The flat is surrounded by "restaurants, cafes, high-street shops, and lively bars" and is close to the main train station, indicating a trendy and transforming area.
# 19
# 20. Gentrifying. The apartment is located on a "lovely cobbled street" with "buildings from the 1600s" and is close to shops, restaurants, and bars, indicating a transforming and desirable area.
# 20
# Submitting batch 7 of 316...
# 1. Established. The neighborhood overview mentions a shopping centre, banks, and public car parks, indicating a well-developed area with existing amenities.
# 1
# 2. NA. The listing lacks sufficient information to assess the gentrification status of the area, as it focuses on the property itself and does not provide details about the neighborhood.
# 2
# 3. Established. The mention of Bolton Town Centre, restaurants, and family-friendly activities suggests a well-known and developed area with existing amenities.
# 3
# 4. Established. The listing mentions Bolton Train station, Town Centre, and a Tesco Esso, indicating a well-developed area with existing amenities.
# 4
# 5. Gentrifying. The mention of award-winning restaurants, boutique shops, and a lively nightlife suggests a transforming area with new cultural and commercial developments.
# 5
# 6. Established. The listing mentions Bolton station, local high street, and Tesco express, indicating a well-developed area with existing amenities, and also highlights the safety and quietness of the private road.
# 6
# 7. Emerging. The mention of a centrally located studio apartment with basic facilities suggests a potentially up-and-coming area, but lacks specific details about new developments or cultural shifts.
# 7
# 8. Undeveloped. The listing lacks specific details about the neighborhood, focusing on the property itself and its amenities, suggesting a lack of notable features or developments in the area.
# 8
# 9. NA. The listing focuses on the property's amenities and does not provide sufficient information to assess the gentrification status of the area.
# 9
# 10. Established. The mention of a main road, bus stops, and train station indicates a well-developed area with existing infrastructure and amenities.
# 10
# 11. Gentrifying. The mention of a freshly renovated property with style and modern finish suggests a transforming area with new developments and investments.
# 11
# 12. Gentrifying. Similar to listing 11, the mention of a freshly renovated property with modern finish and amenities suggests a transforming area with new developments and investments.
# 12
# 13. Established. The listing mentions a quiet and friendly neighborhood with ample parking, parks, and shops within walking distance, indicating a well-developed and stable area.
# 13
# 14. NA. The listing lacks sufficient information to assess the gentrification status of the area, as it only provides basic details about the property and its location.
# 14
# 15. Established. The mention of a quiet and safe residential neighborhood with close access to restaurants, cafes, and public transport suggests a well-developed and stable area.
# 15
# 16. Established. The listing mentions a quiet and friendly neighborhood with close access to Bolton centre, university, hospital, and other amenities, indicating a well-developed area with existing infrastructure.
# 16
# 17. NA. The listing lacks sufficient information to assess the gentrification status of the area, as it only provides basic details about the property and its location, and focuses on promotional offers.
# 17
# 18. Emerging. The mention of a luxury, uniquely designed celebration home with a private garden and high-end amenities suggests a potentially up-and-coming area with new developments and investments.
# 18
# 19. NA. The listing lacks sufficient information to assess the gentrification status of the area, as it only provides basic details about the room and its amenities.
# 19
# 20. Gentrifying. The mention of a fully renovated semi-detached house in a quiet cul-de-sac, with a popular park and amenities within walking distance, suggests a transforming area with new developments and investments.
# 20
# Submitting batch 8 of 316...
# 1. Established. The neighborhood is described as quiet and close to essential amenities like restaurants, shops, and a university, indicating a stable and desirable area.
# 1
# 2. Established. The listing mentions a quiet residential area with easy access to the university and town center, suggesting a well-established neighborhood.
# 2
# 3. Established. The description highlights a quiet residential area with plenty of off-street parking and proximity to the town center, university, and other amenities, indicating a stable and desirable area.
# 3
# 4. Emerging. The mention of a "popular Bolton food street" and a large park suggests some cultural and commercial activity, which could be an early indicator of gentrification.
# 4
# 5. Undeveloped. The listing lacks specific details about the neighborhood, focusing only on the house and its convenience for commuters.
# 5
# 6. Established. The property is described as being close to a shopping center, university, and other amenities, with easy access to Manchester, indicating a well-established area.
# 6
# 7. Emerging. The description mentions a "trendy space" and a "country park" nearby, suggesting some cultural and environmental attractions that could be indicative of early gentrification.
# 7
# 8. NA. The listing lacks sufficient information to assess the gentrification status of the area.
# 8
# 9. Established. The description highlights the property's proximity to woods, country parks, and a busy town with various attractions, indicating a stable and desirable area.
# 9
# 10. NA. The listing lacks sufficient information to assess the gentrification status of the area.
# 10
# 11. Gentrifying. The mention of "immersive public spaces" and a "creative community" suggests recent or ongoing transformation and cultural shifts in the area.
# 11
# 12. Undeveloped. The listing lacks specific details about the neighborhood, focusing only on the property and its general location.
# 12
# 13. Established. The description highlights the property's proximity to a train station, Manchester city center, and other amenities, indicating a stable and desirable area.
# 13
# 14. Gentrifying. The mention of "plenty of restaurants, cafes, shops, and attractions nearby" suggests some commercial and cultural activity, which could be indicative of gentrification.
# 14
# 15. NA. The listing lacks sufficient information to assess the gentrification status of the area.
# 15
# 16. Established. The description mentions a quiet, tree-lined street near the town center, suggesting a stable and desirable neighborhood.
# 16
# 17. Gentrifying. The mention of "stylish furnishings," "modern appliances," and a "lovely cobbled street" suggests some cultural and commercial transformation in the area.
# 17
# 18. Established. The description highlights the property's central location, proximity to bars, restaurants, and shopping malls, indicating a stable and desirable area.
# 18
# 19. Established. The listing mentions a conveniently located flat near the train station, suggesting a well-established and accessible neighborhood.
# 19
# 20. Established. The description highlights the property's proximity to the town center, university, and various parks, indicating a stable and desirable area.
# 20
# Submitting batch 9 of 316...
# 1. Gentrifying. The neighborhood overview highlights Bolton's cultural heritage, scenic landscapes, and bustling urban life, mentioning specific attractions like the Bolton Museum and Octagon Theatre, which suggests development and revitalization.
# 1
#
# 2. Established. The listing focuses on the convenience of the location, with easy access to transportation links and major roads, but lacks descriptive language about the neighborhood's character or cultural scene, implying a well-known and stable area.
# 2
#
# 3. Established. The description mentions the historic neighborhood of Bolton le Moor Church and easy access to transportation links, but the focus is on the convenience and comfort of the stay rather than the neighborhood's cultural or commercial scene.
# 3
#
# 4. Gentrifying. The listing mentions the flat's proximity to shops, restaurants, and public transport, which could indicate a vibrant and developing area, but the description is brief and lacks specific details about the neighborhood's character.
# 4
#
# 5. Established. The listing focuses on the amenities and features of the apartment, with no descriptive language about the neighborhood, suggesting a well-known and desirable area with stable appeal.
# 5
#
# 6. Emerging. The description mentions the proximity to nature reserves and peaceful walking paths, as well as easy access to shops and local amenities, which could indicate a gradual commercial interest in the area, but the focus is on the quiet and peaceful nature of the street.
# 6
#
# 7. NA. The listing lacks sufficient information to make an assessment, as it only mentions the property is a "peaceful place to stay" without providing any details about the neighborhood.
# 7
#
# 8. Gentrifying. The listing describes the town centre as "vibrant" and mentions the combination of convenience and luxury, which suggests a developing and transforming area with new businesses or cultural shifts.
# 8
#
# 9. Gentrifying. The description mentions the property's location in the centre of Bolton, with walking distance to the town centre and train station, which could indicate a vibrant and developing area, and the use of the term "premium HMO" suggests a level of investment and revitalization.
# 9
#
# 10. NA. The listing lacks sufficient information to make an assessment, as it only mentions the property is "family-friendly" and has a modern kitchen and bathroom, without providing any details about the neighborhood.
# 10
#
# 11. NA. The listing lacks sufficient information to make an assessment, as it only mentions the property is "unique and family-friendly" without providing any details about the neighborhood.
# 11
#
# 12. Emerging. The description mentions the property's proximity to the city centre, which could indicate a gradual commercial interest in the area, and the use of the term "beautiful place" suggests a level of appeal and potential for development.
# 12
#
# 13. Emerging. The listing mentions the property's proximity to Manchester and the convenience of the location, which could indicate a gradual commercial interest in the area, and the use of the term "spacious and serene space" suggests a level of appeal and potential for development.
# 13
#
# 14. NA. The listing lacks sufficient information to make an assessment, as it only mentions the property is a "beautiful house" with a "peaceful environment" without providing any details about the neighborhood.
# 14
#
# 15. NA. The listing lacks sufficient information to make an assessment, as it only mentions the property offers a "unique home experience" and "friendly atmosphere" without providing any details about the neighborhood.
# 15
#
# 16. Emerging. The description mentions the property's proximity to the city centre and the convenience of the location, which could indicate a gradual commercial interest in the area, and the use of the term "friendly and peaceful place" suggests a level of appeal and potential for development.
# 16
#
# 17. NA. The listing lacks sufficient information to make an assessment, as it only mentions the property is a "family home" without providing any details about the neighborhood.
# 17
#
# 18. Emerging. The listing mentions the property's proximity to Greater Manchester and the convenience of the location, which could indicate a gradual commercial interest in the area, and the use of the term "nice and specious place" suggests a level of appeal and potential for development.
# 18
#
# 19. Gentrifying. The description mentions the property's location in the town centre, with a busy high street and many food options, which suggests a vibrant and developing area with new businesses or cultural shifts.
# 19
#
# 20. Established. The listing focuses on the features and amenities of the room, with a brief mention of the neighborhood being "friendly, polite and approachable" and having local shops, which suggests a well-known and stable area with a strong sense of community.
# 20
# Submitting batch 10 of 316...
# 1. Emerging. The neighborhood is described as safe and multicultural with plenty of shops, indicating some level of development and community presence.
# 1
# 2. Established. The listing mentions a quiet neighborhood with easy access to Bolton town centre, hospitals, and outdoor activities, suggesting a well-established area.
# 2
# 3. NA. The listing lacks sufficient information about the neighborhood to make an assessment.
# 3
# 4. NA. The listing lacks sufficient information about the neighborhood to make an assessment.
# 4
# 5. NA. The listing lacks sufficient information about the neighborhood to make an assessment.
# 5
# 6. NA. The listing lacks sufficient information about the neighborhood to make an assessment.
# 6
# 7. Established. The property is located near a national country park and provides a central location to the Bolton area, indicating a desirable and established neighborhood.
# 7
# 8. Established. The listing mentions a wide range of local amenities, easy access to Bolton town centre, and a recently refurbished home, suggesting a well-established area.
# 8
# 9. NA. The listing lacks sufficient information about the neighborhood to make an assessment.
# 9
# 10. Established. The property is centrally located with easy access to transport facilities, local shops, and major stores, indicating a well-established area.
# 10
# 11. Gentrifying. The listing mentions a newly refurbished house, easy access to town centre, and various amenities, suggesting recent development and investment in the area.
# 11
# 12. Emerging. The listing mentions a stylish experience, breakfast available, and a 2-minute walk to a local park, indicating some level of development and amenities.
# 12
# 13. NA. The listing lacks sufficient information about the neighborhood to make an assessment.
# 13
# 14. Emerging. The property is located in a brand new estate with ongoing construction work, suggesting early stages of development.
# 14
# 15. NA. The listing lacks sufficient information about the neighborhood to make an assessment.
# 15
# 16. Established. The listing mentions a wide range of independent shops, a market, bars, and restaurants in Westhoughton town centre, indicating a well-established and desirable area.
# 16
# 17. Established. The listing describes the area as posh and exclusive with a clean environment, suggesting a well-established and desirable neighborhood.
# 17
# 18. Established. The listing mentions a highly desirable and safe village with a local pub, church, and football club, indicating a well-established and community-oriented area.
# 18
# 19. Established. The listing mentions a greenbelt village with great public transport links and a secure gated drive, suggesting a well-established and desirable area.
# 19
# 20. Emerging. The listing mentions easy access to Manchester City and local train station, as well as fantastic trekking tracks nearby, indicating some level of development and amenities.
# 20
# Submitting batch 11 of 316...
# 1. Undeveloped. The listing focuses on proximity to transportation links and external attractions rather than local neighborhood features.
# 1
# 2. Undeveloped. The listing lacks any description of the neighborhood or local amenities.
# 2
# 3. Emerging. The mention of local shops, a country park, and a farm ice-cream shop suggests some community features, but it does not indicate a highly developed or trendy area.
# 3
# 4. Undeveloped. The listing does not provide any information about the neighborhood or local amenities.
# 4
# 5. Established. The description of a quiet close and a garden backing onto farmland, along with amenities like a pool table and gym equipment, suggests a desirable and possibly affluent area.
# 5
# 6. Undeveloped. The listing is too vague, mentioning "nice views" and "good amenities" without specifying what these are.
# 6
# 7. Gentrifying. The mention of being close to major roads and having local amenities like a Co-op and Tesco express, along with the presence of a leisure centre and stadium, suggests an area with developing infrastructure and attractions.
# 7
# 8. Gentrifying. The description of Westhoughton as having shops, restaurants, cafes, and pubs within walking distance, along with proximity to a university stadium and retail parks, indicates an area with a mix of local amenities and larger commercial developments.
# 8
# 9. Established. The mention of a greenbelt village with great public transport links and secure parking suggests a desirable and possibly affluent area.
# 9
# 10. Established. The description of uninterrupted views and a cosy cottage feel, along with proximity to nature and commutability to neighbouring cities, suggests a desirable and peaceful area.
# 10
# 11. Emerging. The mention of being close to public transport, a town centre, and various restaurants and shops suggests an area with some local amenities, but it does not indicate a highly developed or trendy area.
# 11
# 12. Undeveloped. The listing focuses on the room itself and mentions a quiet residential estate but lacks detail about local amenities or neighborhood features.
# 12
# 13. Gentrifying. The description of the property as "luxury" and "chic" in Darley Grove suggests an area that may be undergoing some form of redevelopment or gentrification to support high-end accommodations.
# 13
# 14. NA. The listing describes the interior of the living room in detail but does not provide any information about the neighborhood or local amenities.
# 14
# 15. Emerging. The mention of a new build estate suggests some level of development or construction in the area, which could be an early indicator of gentrification.
# 15
# 16. Undeveloped. The listing mentions proximity to a small village and a major motorway junction but lacks detail about local amenities or neighborhood features.
# 16
# 17. Undeveloped. The listing lacks any description of the neighborhood or local amenities, focusing instead on the property's features.
# 17
# 18. Established. The mention of "great links to the city" suggests an area that is well-connected and possibly desirable, but the lack of hustle and bustle implies it may not be a central or highly gentrified area.
# 18
# 19. Undeveloped. The listing mentions proximity to a hospital and city centre but lacks detail about local amenities or neighborhood features.
# 19
# 20. Gentrifying. The description of the apartment as "modern" and its location in the Farnworth axis of Bolton, with proximity to a hospital and university, suggests an area that may be developing or revitalizing.
# 20
# Submitting batch 12 of 316...
# 1. Undeveloped. The listing lacks specific details about the neighborhood, focusing instead on the property's location relative to motorway networks and Manchester Airport.
# 1
#
# 2. Undeveloped. The description does not provide detailed information about the neighborhood, focusing on general amenities like parking and proximity to the hospital and motorways.
# 2
#
# 3. Undeveloped. Similar to the previous listings, this one focuses on the property's amenities and distances to various landmarks without describing the neighborhood itself.
# 3
#
# 4. Emerging. The mention of easy motorway access, local shops, and a quiet residential area suggests some level of development, but it does not indicate a vibrant or transforming community.
# 4
#
# 5. Emerging. The description of a short walk to the train station, proximity to pubs, convenience stores, and an Italian restaurant, suggests a modest level of local amenities, indicating potential for gentrification.
# 5
#
# 6. Gentrifying. The mention of a Victorian mid-terr house renovated to a high standard, excellent rail and motorway links, and recommendations for local eateries and the Northern Quarter, suggests an area undergoing transformation.
# 6
#
# 7. Undeveloped. The listing is vague about the neighborhood, focusing on the property's suitability for various types of travelers without describing local amenities or attractions.
# 7
#
# 8. Emerging. The description of a renovated, modern space with great views, accessible to various locations, and a rural setting with local walks, suggests an area that is developing or has potential for gentrification.
# 8
#
# 9. Emerging. The newly built area overlooking the River Irwell, with a 10-minute walk to the train station and a quiet, safe neighborhood, indicates some level of development or investment in the area.
# 9
#
# 10. Gentrifying. The description of a stylish open-plan living apartment in Stoneclough village, with stunning river views, close to local pubs, restaurants, and shops, suggests an area that is transforming or has been recently developed.
# 10
#
# 11. Emerging. The peaceful and beautiful location next to Kearsley train station with direct access to Manchester, Salford, and Bolton, suggests potential for gentrification due to its connectivity.
# 11
#
# 12. Emerging. Similar to the previous listing, the emphasis on the property's location in a picturesque village with great connections to city centers indicates potential for development.
# 12
#
# 13. Emerging. The description of a peaceful, refurbished property with outstanding motorway links, short walking distance to local pubs and grocery, and nice walks nearby, suggests an area that is developing or has potential for gentrification.
# 13
#
# 14. Undeveloped. The focus on the property's amenities within a gated community, without detailed description of the surrounding neighborhood, does not provide enough information to assess gentrification status.
# 14
#
# 15. Emerging. The location in a quiet area of Daisy Hill, Westhoughton, with ideal transport links, close to a nature reserve and children's park, suggests some level of development or potential for gentrification.
# 15
#
# 16. NA. This listing appears to describe a location outside of the Bolton area, possibly in Spain, given the mention of a marina and beach, and thus cannot be assessed in the context of the other listings.
# 16
#
# 17. Established. The description of Ramsbottom as a former mill town with a thriving food and drink scene, award-winning high street, and numerous amenities within walking distance, suggests a well-established and desirable area.
# 17
#
# 18. Established. Similar to the previous listing, the description of Ramsbottom as a lovely town with lots of nice restaurants, pubs, bars, shops, and the local Irwell Brewery, indicates a well-developed and attractive area.
# 18
#
# 19. Established. The portrayal of Ramsbottom as a gorgeous, quirky town with a bustling high street, fantastic restaurants, and beautiful parks, confirms its status as a well-established and desirable location.
# 19
#
# 20. Established. The description of a centrally located apartment in Ramsbottom, close to bars, restaurants, and supermarkets, with easy access to walking and cycling routes, further reinforces the area's established status.
# 20
# Submitting batch 13 of 316...
# 1. Gentrifying. The listing highlights the area's upscale features, such as Michelin eats and heritage museums, indicating a transformation towards a more desirable and affluent neighborhood.
# 1
#
# 2. Emerging. The description of the market town as "oozing quaintness" and having "Victorian architecture" and "industrial heritage" suggests a potential for gentrification, with the area's unique character being emphasized as a selling point.
# 2
#
# 3. Gentrifying. The mention of award-winning eateries, pubs, and independent shops, as well as events like the Ramsbottom Chocolate Festival, indicates a thriving and vibrant community, likely a result of gentrification efforts.
# 3
#
# 4. Emerging. The emphasis on the peaceful and idyllic setting, as well as the proximity to Ramsbottom, suggests that the area is being positioned as a desirable and potentially up-and-coming destination.
# 4
#
# 5. Gentrifying. The description of the area as having "bars, restaurants, take aways and walks in the local countryside" within walking distance, as well as the mention of an award-winning local pub, indicates a level of development and investment in the neighborhood.
# 5
#
# 6. Undeveloped. The listing lacks specific details about the neighborhood, instead focusing on the property's amenities and location in relation to larger cities, suggesting that the immediate area may not be a major selling point.
# 6
#
# 7. Gentrifying. The mention of "award-winning eateries, pubs, bars, independent shops" and "regular bus routes" indicates a level of development and investment in the neighborhood, likely a result of gentrification efforts.
# 7
#
# 8. Gentrifying. The emphasis on the area's accessibility and proximity to attractions like Peel Tower and Holcombe Moors, as well as the mention of a "town center" with shops and restaurants, suggests a level of development and investment in the neighborhood.
# 8
#
# 9. NA. The listing lacks sufficient information about the neighborhood to make an assessment.
# 9
#
# 10. Gentrifying. The description of the area as having "bars, shops and restaurants within walking distance" and being "pet friendly" suggests a level of development and investment in the neighborhood, likely a result of gentrification efforts.
# 10
#
# 11. Gentrifying. The mention of a "thriving and popular" town center with "many eateries and pubs" and the sound of steam trains suggests a vibrant and desirable community, likely a result of gentrification efforts.
# 11
#
# 12. Gentrifying. The description of the area as being within walking distance to Ramsbottom town center, with its shops, cafes, and restaurants, indicates a level of development and investment in the neighborhood.
# 12
#
# 13. Gentrifying. The mention of "quirky bars, shops & restaurants" and the proximity to Manchester suggests a level of development and investment in the neighborhood, likely a result of gentrification efforts.
# 13
#
# 14. Emerging. The description of the cottage as being located in a historic building and having a "cosy" atmosphere suggests a potential for gentrification, with the area's unique character being emphasized as a selling point.
# 14
#
# 15. Undeveloped. The listing lacks specific details about the neighborhood, instead focusing on the property's amenities and location in relation to larger cities, suggesting that the immediate area may not be a major selling point.
# 15
#
# 16. Gentrifying. The mention of "quirky bars and eatery" and "traditional pub" suggests a level of development and investment in the neighborhood, likely a result of gentrification efforts.
# 16
#
# 17. NA. The listing lacks sufficient information about the neighborhood to make an assessment.
# 17
#
# 18. NA. The listing lacks sufficient information about the neighborhood to make an assessment.
# 18
#
# 19. Gentrifying. The description of Ramsbottom as being "well known for lovely walks nearby" and having a "music scene, restaurants, cosy pubs, shopping, independent shops" suggests a level of development and investment in the neighborhood, likely a result of gentrification efforts.
# 19
#
# 20. Emerging. The description of the area as having a "peaceful" atmosphere and being located near the River Irwell and the East Lancashire steam Railway suggests a potential for gentrification, with the area's unique character being emphasized as a selling point.
# 20
# Submitting batch 14 of 316...
# 1. Established. The neighborhood is described as picturesque with established attractions like walking, fishing, and golf, indicating a stable and desirable area.
# 1
# 2. Established. The description focuses on the natural surroundings and nearby golf clubs, suggesting a well-established and peaceful area.
# 2
# ...
# 10
# 11. Established. The mention of easy access to local hospitals, businesses, and attractions suggests a well-established area, and the description of a perfect blend of privacy and community implies a stable neighborhood.
# 11
# 12. Established. The description of a charming home with amenities like a hot tub and pool table suggests a well-established and desirable area.
# 12
# 13. Established. The mention of a quiet estate and easy access to Wigan town centre suggests a well-established neighborhood.
# 13
# 14. Established. The description of a convenient location with easy access to Wigan town centre, green parks, and cultural attractions suggests a well-established area.
# 14
# 15. Emerging. The description of a cosy house perfect for contractors or professionals implies some development, but the area is not described as a cultural hotspot.
# 15
# 16. NA. The listing lacks sufficient information about the neighborhood to make an assessment.
# 16
# 17. Gentrifying. The description of a refurbished property in a centrally-located area with amazing restaurants, cafes, and bars suggests recent transformation and cultural development.
# 17
# 18. Established. The mention of a great location for restaurants, bars, shopping, and takeaways suggests a well-established area, and the description of easy motorway access implies a stable neighborhood.
# 18
# 19. Emerging. The description of a duplex flat with private parking and easy access to the city centre suggests some development, but the area is not described as a cultural hotspot.
# 19
# 20. Gentrifying. The description of a charming Victorian terrace converted into a spacious apartment, with a lively town filled with shops, cafes, bars, and restaurants, suggests recent transformation and cultural development.
# 20
# Submitting batch 313 of 316...
# 1. Undeveloped. The listing lacks specific details about the neighborhood, only mentioning its location in relation to Greater Manchester.
# 1
# 2. Established. The description highlights a quiet, mixed neighborhood with friendly neighbors and easy access to local attractions and major roads.
# 2
# 3. Emerging. The mention of a new development, a nature reserve, and local amenities suggests potential for growth and gentrification.
# 3
# 4. NA. The listing does not provide sufficient information about the neighborhood to make an assessment.
# 4
# 5. Established. The description emphasizes a quiet cul-de-sac, friendly neighbors, and local convenience stores, indicating a stable and desirable area.
# 5
# 6. Emerging. The proximity to a retail park, town center, and easy commute to Manchester suggests potential for development and gentrification.
# 6
# 7. NA. The listing focuses on the property's amenities and lacks specific details about the neighborhood.
# 7
# 8. Established. The description highlights a quiet residential neighborhood with a cul-de-sac, indicating a stable and peaceful area.
# 8
# 9. NA. The listing lacks sufficient information about the neighborhood to make an assessment.
# 9
# 10. NA. The listing does not provide any details about the neighborhood.
# 10
# 11. Established. The description mentions proximity to various cities and attractions, suggesting a well-connected and desirable area.
# 11
# 12. Emerging. The listing highlights several local amenities, retail parks, and easy commute to Manchester, indicating potential for growth and gentrification.
# 12
# 13. Gentrifying. The description emphasizes a lively neighborhood with shops, cafes, and restaurants, as well as proximity to a country park and sports village, suggesting ongoing transformation.
# 13
# 14. Emerging. The mention of a quiet cul-de-sac and easy access to major roads and city centers suggests potential for development and gentrification.
# 14
# 15. NA. The listing lacks sufficient information about the neighborhood to make an assessment.
# 15
# 16. Emerging. The description highlights easy access to buses and a convenient location, indicating potential for growth and gentrification.
# 16
# 17. Established. The description emphasizes a cozy house with modern decor and convenient location, suggesting a stable and desirable area.
# 17
# 18. Emerging. The mention of a picturesque village with beautiful open walks and access to sporting groups suggests potential for growth and gentrification.
# 18
# 19. Gentrifying. The description highlights a leafy village with modern cafes, coffee shops, and local pubs, as well as proximity to a guided busway, suggesting ongoing transformation.
# 19
# 20. Emerging. The listing mentions a recently revamped property and easy commute to Manchester, Liverpool, and the motorway network, indicating potential for growth and gentrification.
# 20
# Submitting batch 314 of 316...
# 1. Emerging. The neighborhood is described as a "lovely little village" with a pub and a complex with restaurants, indicating some local amenities and potential for gentrification.
# 1
# 2. Established. The listing mentions a "local village with friendly pubs, restaurants, and cafes," as well as historic attractions and a museum, suggesting a well-established and desirable area.
# 2
# 3. Undeveloped. The neighborhood is described as "quiet" with easy access to shops and a bus stop, but lacks specific details about local attractions or amenities.
# 3
# 4. NA. The listing lacks sufficient information to assess the gentrification status of the area.
# 4
# 5. NA. The listing focuses on the property's amenities and lacks information about the neighborhood.
# 5
# 6. Established. The area is described as a "small, friendly community" with local facilities and a central common, indicating a stable and desirable neighborhood.
# 6
# 7. Emerging. The neighborhood is described as "very quiet" with shops and a restaurant within walking distance, suggesting some local amenities and potential for gentrification.
# 7
# 8. Emerging. The listing mentions a "new build estate" and a "walk track," indicating some development and potential for growth.
# 8
# 9. NA. The listing lacks sufficient information to assess the gentrification status of the area.
# 9
# 10. Established. The listing mentions several local supermarkets, restaurants, and tourist sites, suggesting a well-established and desirable area.
# 10
# 11. Gentrifying. The property is located in "Leigh City Centre" with close proximity to the bus station, restaurants, and shops, indicating some urban development and potential for gentrification.
# 11
# 12. Emerging. The neighborhood is described as a "quiet street" with a big retail park within walking distance, suggesting some local amenities and potential for gentrification.
# 12
# 13. Established. The property is located in the "heart of Leigh" with excellent transport links and historic charm, indicating a well-established and desirable area.
# 13
# 14. Gentrifying. The listing mentions a "newly renovated property" and proximity to local attractions and transport links, suggesting some development and potential for gentrification.
# 14
# 15. Emerging. The neighborhood is described as "friendly" with great transport links and easy access to popular shops and restaurants, indicating some local amenities and potential for gentrification.
# 15
# 16. Emerging. The property is located in a "beautiful neighborhood" with a "tight security system" and brand new furniture, suggesting some development and potential for gentrification.
# 16
# 17. Established. The area is described as a "nice quiet side street" with easy access to amenities and transport links, indicating a stable and desirable neighborhood.
# 17
# 18. Emerging. The listing mentions a "brand new garden annexe" and proximity to transport links and local attractions, suggesting some development and potential for gentrification.
# 18
# 19. Gentrifying. The property is located near several local attractions and transport links, including a sports village and retail park, indicating some urban development and potential for gentrification.
# 19
# 20. Emerging. The neighborhood is described as a "peaceful close" with "breathtaking views" and a "serene atmosphere," suggesting some natural amenities and potential for gentrification.
# 20
# Submitting batch 315 of 316...
# 1. Undeveloped. The listing lacks specific details about the neighborhood, focusing only on the property itself.
# 1
# 2. Established. The neighborhood is described with specific local attractions and amenities, indicating a well-known and desirable area.
# 2
# 3. Undeveloped. Similar to the first listing, this one focuses on the property's features without providing detailed information about the neighborhood.
# 3
# 4. Established. The listing mentions the proximity to Leigh Sports Village and the convenience of local amenities, suggesting a stable and appealing area.
# 4
# 5. Undeveloped. The description does not provide specific details about the neighborhood, focusing instead on the property's comfort and convenience.
# 5
# 6. Established. The listing highlights various local supermarkets, restaurants, and tourist sites, indicating a well-developed and desirable area.
# 6
# 7. Undeveloped. This listing lacks detailed information about the neighborhood, focusing primarily on the property's features.
# 7
# 8. Emerging. The mention of a "quiet residential area" and walking distance to Leigh Town Centre suggests potential for gentrification, with new developments and amenities.
# 8
# 9. Established. The description of easy access to Wigan town centre, Manchester, and Liverpool, along with the mention of a convenience shop, indicates a well-connected and desirable area.
# 9
# 10. Established. The listing mentions the proximity to Haydock racecourse and the convenience of local amenities, suggesting a stable and appealing area.
# 10
# 11. Emerging. The description of a "quiet and friendly neighbourhood" with the presence of a relocation agency suggests potential for new developments and gentrification.
# 11
# 12. Established. The listing highlights the convenience of the location, with proximity to Warrington, Manchester, and Liverpool, indicating a well-connected and desirable area.
# 12
# 13. Emerging. The mention of new amenities and easy access to major roads suggests potential for gentrification and development in the area.
# 13
# 14. Undeveloped. The listing lacks specific details about the neighborhood, focusing instead on the property's features and convenience.
# 14
# 15. Established. The description of a conservation area with traditional pubs, restaurants, and trendy bars suggests a well-developed and desirable area.
# 15
# 16. Established. The listing mentions the proximity to Haydock racecourse and local shops, bars, and restaurants, indicating a stable and appealing area.
# 16
# 17. Emerging. The description of a "unique and private stay" with a remodeled modern space and proximity to local walks and good food pubs suggests potential for gentrification and development.
# 17
# 18. Established. The listing highlights the proximity to Leigh Sports Village and Pennington Flash country park, indicating a well-developed and desirable area.
# 18
# 19. Established. The description of a "vibrant neighborhood" with a friendly community, nearby parks, and excellent transport links suggests a well-connected and desirable area.
# 19
# 20. Established. The listing mentions the proximity to Leigh Sports Village and Pennington Flash, as well as easy access to major roads, indicating a well-developed and desirable area.
# 20
# Submitting batch 316 of 316...
# 1. Emerging. The neighborhood is described as peaceful and green with shops nearby, indicating a potentially up-and-coming area with some commercial interest.
# 1
# 2. Established. The listing mentions a local town centre, parks, and easy access to larger cities like Manchester and Liverpool, suggesting a well-developed and stable area.
# 2
# 3. Emerging. The area is described as a quiet leafy residential area surrounded by open countryside, with a short walk to Pennington Flash country park, indicating some natural attractions and potential for growth.
# 3
# 4. Emerging. Similar to listing 3, this area is described as a lovely tree-lined suburban area surrounded by countryside, with nearby parks and a short walk to local shops, suggesting a quiet but potentially developing neighborhood.
# 4
# 5. Established. The village of Edge Green is described as small but bustling, with a few shops and a local pub, and easy access to larger cities, indicating a well-established community.
# 5
# 6. Gentrifying. The listing mentions the bustling heart of Golborne village, with newly refurbished apartments, cafes, shops, and easy access to larger cities, suggesting recent development and investment in the area.
# 6
# 7. Emerging. The neighborhood is described as charming and convenient, with easy access to local shops and public transport, but lacks specific details about the area's character or attractions.
# 7
# 8. Undeveloped. The listing lacks any detailed description of the neighborhood, suggesting that the area may not be a major selling point or may be undeveloped.
# 8
# 9. Established. Golborne is described as a small but bustling town with a strong sense of community, hosting local events and having easy access to the countryside and larger towns, indicating a well-established and stable area.
# 9
# 10. Emerging. The neighborhood is described as nice, with a supermarket and local pubs nearby, and some lovely parks, suggesting a quiet but potentially developing area.
# 10
# 11. Gentrifying. The listing mentions a newly renovated house in a quiet residential area, with many local shops, pubs, and restaurants, and easy access to larger cities, suggesting recent investment and development in the area.
# 11
# 12. Gentrifying. Similar to listing 6, this listing describes the bustling heart of Golborne village, with newly refurbished apartments and easy access to larger cities, indicating recent development and investment in the area.
# 12
# 13. Emerging. The area is described as a peaceful and beautiful development area, suggesting potential for growth and development.
# 13
# 14. Established. The listing mentions a delightful outdoor seating area and easy access to Liverpool, suggesting a well-established and desirable area.
# 14
# 15. Undeveloped. The listing focuses on the property's central location and accessibility to major road networks, but lacks any detailed description of the neighborhood, suggesting that the area may not be a major selling point or may be undeveloped.
# 15
# 16. Established. The property is situated in a Grade II Listed Farmhouse with easy proximity to various attractions and major road networks, indicating a well-established and desirable area.
# 16
# 17. Established. The listing describes a charming barn conversion with easy access to larger cities and attractions, suggesting a well-established and desirable area.
# 17
# 18. Emerging. The listing mentions a newly renovated property in Lowton, with nearby attractions like Pennington flash and Leigh sports village, and easy access to larger cities, suggesting potential for growth and development.
# 18
# 19. Emerging. The area is described as a beautiful village between Liverpool and Manchester, suggesting a potentially desirable and developing neighborhood.
# 19
# 20. Undeveloped. The listing focuses on the property's amenities and services, but lacks any detailed description of the neighborhood, suggesting that the area may not be a major selling point or may be undeveloped.
# 20
# Submitting batch 2107 of 2107...
# 1. Established. The neighborhood is described as "peaceful" and "quite", suggesting a stable and desirable area with little active change.
# 1
# 2. Established. The listing provides a detailed overview of nearby amenities, including supermarkets, eateries, and leisure facilities, indicating a well-established area with a range of services and attractions.
# 2
# 3. Emerging. The listing highlights the property's location between two major cities and its accessibility to motorways and public transport, suggesting potential for growth and development, but lacks specific details about the local neighborhood or community.
# 3
# Finished querying LLM. Now saving file
# File saved as: ../../../data/AirbnbData/airbnb-manchester/airbnb_gentrification_scores_new_02.csv
